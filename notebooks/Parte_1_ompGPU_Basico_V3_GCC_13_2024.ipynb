# %% [markdown]
# # Programe sua GPU com OpenMP
#
# Autores:
# _Hermes Senger_ e
# _Jaime Freire de Souza_
#
# Data de criação: 16/04/2022
#
# Última modificação:
#
#     24/04/2024 - Instalação do gcc13
#
# ## Configuração do ambiente
#
# Precisaremos de um compilador capaz de gerar código executável para GPUs. O GCC 13 faz isso. Também precisaremos do CUDA, mas esse já está previamente instalado.
#
# ```
# # This is formatted as code
# ```

# %%
# %%shell
# #ajustar repositorio de compiladores
# true | add-apt-repository ppa:ubuntu-toolchain-r/test
# Out:
# PPA publishes dbgsym, you may need to include 'main/debug' component
# Repository: 'deb https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu/ jammy main'
# Description:
# Toolchain test builds; see https://wiki.ubuntu.com/ToolChain
#
# More info: https://launchpad.net/~ubuntu-toolchain-r/+archive/ubuntu/test
# Adding repository.
# Adding deb entry to /etc/apt/sources.list.d/ubuntu-toolchain-r-ubuntu-test-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/ubuntu-toolchain-r-ubuntu-test-jammy.list
# Adding key to /etc/apt/trusted.gpg.d/ubuntu-toolchain-r-ubuntu-test.gpg with fingerprint 60C317803A41BA51845E371A1E9377A2BA9EF27F
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:10 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy InRelease [23.8 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [2,259 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,753 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,077 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,339 kB]
# Get:16 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 Packages [17.4 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,369 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,035 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.0 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [110 kB]
# Fetched 11.4 MB in 9s (1,271 kB/s)
# Reading package lists... Done

# %%
# %%shell
# #instalar gcc 13 e primos
# apt install gcc-13 g++-13 gcc-13-offload-nvptx libgomp1
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-13 gcc-13-base libasan8 libatomic1 libcc1-0 libgcc-13-dev libgcc-s1 libgomp-plugin-nvptx1
#   libhwasan0 libitm1 liblsan0 libquadmath0 libstdc++-13-dev libstdc++6 libtsan2 libubsan1
#   nvptx-tools
# Suggested packages:
#   gcc-13-locales cpp-13-doc g++-13-multilib gcc-13-doc gcc-13-multilib libcuda1
#   | libnvidia-tesla-cuda1 | libcuda1-any libstdc++-13-doc nvidia-cuda-toolkit
# The following NEW packages will be installed:
#   cpp-13 g++-13 gcc-13 gcc-13-base gcc-13-offload-nvptx libasan8 libgcc-13-dev
#   libgomp-plugin-nvptx1 libhwasan0 libstdc++-13-dev libtsan2 nvptx-tools
# The following packages will be upgraded:
#   libatomic1 libcc1-0 libgcc-s1 libgomp1 libitm1 liblsan0 libquadmath0 libstdc++6 libubsan1
# 9 upgraded, 12 newly installed, 0 to remove and 49 not upgraded.
# Need to get 271 MB of archives.
# After this operation, 834 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 nvptx-tools amd64 0.20180301-1build1 [28.2 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 gcc-13-base amd64 13.1.0-8ubuntu1~22.04 [19.7 kB]
# Get:3 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libgcc-s1 amd64 13.1.0-8ubuntu1~22.04 [62.9 kB]
# Get:4 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libstdc++6 amd64 13.1.0-8ubuntu1~22.04 [792 kB]
# Get:5 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 cpp-13 amd64 13.1.0-8ubuntu1~22.04 [60.7 MB]
# Get:6 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libcc1-0 amd64 13.1.0-8ubuntu1~22.04 [48.6 kB]
# Get:7 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libgomp1 amd64 13.1.0-8ubuntu1~22.04 [144 kB]
# Get:8 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libitm1 amd64 13.1.0-8ubuntu1~22.04 [30.2 kB]
# Get:9 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libatomic1 amd64 13.1.0-8ubuntu1~22.04 [10.4 kB]
# Get:10 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libasan8 amd64 13.1.0-8ubuntu1~22.04 [2,842 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 liblsan0 amd64 13.1.0-8ubuntu1~22.04 [1,211 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libtsan2 amd64 13.1.0-8ubuntu1~22.04 [2,623 kB]
# Get:13 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libubsan1 amd64 13.1.0-8ubuntu1~22.04 [1,113 kB]
# Get:14 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libhwasan0 amd64 13.1.0-8ubuntu1~22.04 [1,271 kB]
# Get:15 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libquadmath0 amd64 13.1.0-8ubuntu1~22.04 [155 kB]
# Get:16 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libgcc-13-dev amd64 13.1.0-8ubuntu1~22.04 [2,733 kB]
# Get:17 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 gcc-13 amd64 13.1.0-8ubuntu1~22.04 [70.2 MB]
# Get:18 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libstdc++-13-dev amd64 13.1.0-8ubuntu1~22.04 [2,343 kB]
# Get:19 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 g++-13 amd64 13.1.0-8ubuntu1~22.04 [65.8 MB]
# Get:20 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 libgomp-plugin-nvptx1 amd64 13.1.0-8ubuntu1~22.04 [14.9 kB]
# Get:21 https://ppa.launchpadcontent.net/ubuntu-toolchain-r/test/ubuntu jammy/main amd64 gcc-13-offload-nvptx amd64 13.1.0-8ubuntu1~22.04 [58.4 MB]
# Fetched 271 MB in 19s (14.2 MB/s)
# Selecting previously unselected package gcc-13-base:amd64.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../gcc-13-base_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking gcc-13-base:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up gcc-13-base:amd64 (13.1.0-8ubuntu1~22.04) ...
# (Reading database ... 121757 files and directories currently installed.)
# Preparing to unpack .../libgcc-s1_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libgcc-s1:amd64 (13.1.0-8ubuntu1~22.04) over (12.3.0-1ubuntu1~22.04) ...
# Setting up libgcc-s1:amd64 (13.1.0-8ubuntu1~22.04) ...
# (Reading database ... 121757 files and directories currently installed.)
# Preparing to unpack .../libstdc++6_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libstdc++6:amd64 (13.1.0-8ubuntu1~22.04) over (12.3.0-1ubuntu1~22.04) ...
# Setting up libstdc++6:amd64 (13.1.0-8ubuntu1~22.04) ...
# Selecting previously unselected package cpp-13.
# (Reading database ... 121757 files and directories currently installed.)
# Preparing to unpack .../00-cpp-13_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking cpp-13 (13.1.0-8ubuntu1~22.04) ...
# Preparing to unpack .../01-libcc1-0_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libcc1-0:amd64 (13.1.0-8ubuntu1~22.04) over (12.3.0-1ubuntu1~22.04) ...
# Preparing to unpack .../02-libgomp1_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libgomp1:amd64 (13.1.0-8ubuntu1~22.04) over (12.3.0-1ubuntu1~22.04) ...
# Preparing to unpack .../03-libitm1_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libitm1:amd64 (13.1.0-8ubuntu1~22.04) over (12.3.0-1ubuntu1~22.04) ...
# Preparing to unpack .../04-libatomic1_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libatomic1:amd64 (13.1.0-8ubuntu1~22.04) over (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libasan8:amd64.
# Preparing to unpack .../05-libasan8_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libasan8:amd64 (13.1.0-8ubuntu1~22.04) ...
# Preparing to unpack .../06-liblsan0_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking liblsan0:amd64 (13.1.0-8ubuntu1~22.04) over (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libtsan2:amd64.
# Preparing to unpack .../07-libtsan2_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libtsan2:amd64 (13.1.0-8ubuntu1~22.04) ...
# Preparing to unpack .../08-libubsan1_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libubsan1:amd64 (13.1.0-8ubuntu1~22.04) over (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libhwasan0:amd64.
# Preparing to unpack .../09-libhwasan0_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libhwasan0:amd64 (13.1.0-8ubuntu1~22.04) ...
# Preparing to unpack .../10-libquadmath0_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libquadmath0:amd64 (13.1.0-8ubuntu1~22.04) over (12.3.0-1ubuntu1~22.04) ...
# Selecting previously unselected package libgcc-13-dev:amd64.
# Preparing to unpack .../11-libgcc-13-dev_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libgcc-13-dev:amd64 (13.1.0-8ubuntu1~22.04) ...
# Selecting previously unselected package gcc-13.
# Preparing to unpack .../12-gcc-13_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking gcc-13 (13.1.0-8ubuntu1~22.04) ...
# Selecting previously unselected package libstdc++-13-dev:amd64.
# Preparing to unpack .../13-libstdc++-13-dev_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libstdc++-13-dev:amd64 (13.1.0-8ubuntu1~22.04) ...
# Selecting previously unselected package g++-13.
# Preparing to unpack .../14-g++-13_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking g++-13 (13.1.0-8ubuntu1~22.04) ...
# Selecting previously unselected package nvptx-tools.
# Preparing to unpack .../15-nvptx-tools_0.20180301-1build1_amd64.deb ...
# Unpacking nvptx-tools (0.20180301-1build1) ...
# Selecting previously unselected package libgomp-plugin-nvptx1:amd64.
# Preparing to unpack .../16-libgomp-plugin-nvptx1_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking libgomp-plugin-nvptx1:amd64 (13.1.0-8ubuntu1~22.04) ...
# Selecting previously unselected package gcc-13-offload-nvptx.
# Preparing to unpack .../17-gcc-13-offload-nvptx_13.1.0-8ubuntu1~22.04_amd64.deb ...
# Unpacking gcc-13-offload-nvptx (13.1.0-8ubuntu1~22.04) ...
# Setting up cpp-13 (13.1.0-8ubuntu1~22.04) ...
# Setting up libgomp1:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libquadmath0:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libatomic1:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libubsan1:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libhwasan0:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libasan8:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up nvptx-tools (0.20180301-1build1) ...
# Setting up libtsan2:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libcc1-0:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up liblsan0:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libitm1:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libgomp-plugin-nvptx1:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libgcc-13-dev:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up libstdc++-13-dev:amd64 (13.1.0-8ubuntu1~22.04) ...
# Setting up gcc-13 (13.1.0-8ubuntu1~22.04) ...
# Setting up g++-13 (13.1.0-8ubuntu1~22.04) ...
# Setting up gcc-13-offload-nvptx (13.1.0-8ubuntu1~22.04) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link

# %%
# !nvcc --version
# !ls -l /usr/bin
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# total 322860
# -rwxr-xr-x 1 root root       51632 Feb  7  2022 '['
# -rwxr-xr-x 1 root root          39 Aug 15  2020  7z
# -rwxr-xr-x 1 root root          40 Aug 15  2020  7za
# -rwxr-xr-x 1 root root          40 Aug 15  2020  7zr
# lrwxrwxrwx 1 root root          25 Apr 23 13:18  aclocal -> /etc/alternatives/aclocal
# -rwxr-xr-x 1 root root       36020 Mar 18  2022  aclocal-1.16
# -rwxr-xr-x 1 root root       18656 Feb  6  2022  acyclic
# -rwxr-xr-x 1 root root       14478 Oct 24  2023  add-apt-repository
# -rwxr-xr-x 1 root root       14712 Feb 21  2022  addpart
# lrwxrwxrwx 1 root root          26 Jun  4  2023  addr2line -> x86_64-linux-gnu-addr2line
# -rwxr-xr-x 1 root root        1887 Mar  4  2022  aggregate_profile
# lrwxrwxrwx 1 root root           6 Mar 17  2022  apropos -> whatis
# -rwxr-xr-x 1 root root       18824 Feb 13 15:39  apt
# lrwxrwxrwx 1 root root          18 Oct 24  2023  apt-add-repository -> add-apt-repository
# -rwxr-xr-x 1 root root       84448 Feb 13 15:39  apt-cache
# -rwxr-xr-x 1 root root       27104 Feb 13 15:39  apt-cdrom
# -rwxr-xr-x 1 root root       27024 Feb 13 15:39  apt-config
# -rwxr-xr-x 1 root root       23008 Feb 13 15:39  apt-extracttemplates
# -rwxr-xr-x 1 root root      236008 Feb 13 15:39  apt-ftparchive
# -rwxr-xr-x 1 root root       51680 Feb 13 15:39  apt-get
# -rwxr-xr-x 1 root root       28173 Feb 13 15:39  apt-key
# -rwxr-xr-x 1 root root       51680 Feb 13 15:39  apt-mark
# -rwxr-xr-x 1 root root       39320 Feb 13 15:39  apt-sortpkgs
# lrwxrwxrwx 1 root root          19 Jun  4  2023  ar -> x86_64-linux-gnu-ar
# -rwxr-xr-x 1 root root       31232 Feb  7  2022  arch
# lrwxrwxrwx 1 root root          19 Jun  4  2023  as -> x86_64-linux-gnu-as
# lrwxrwxrwx 1 root root          17 Apr  1  2022  asan_symbolize -> asan_symbolize-14
# -rwxr-xr-x 1 root root       38140 Jul 14  2023  asan_symbolize-14
# -rwxr-xr-x 1 root root       15204 Aug 23  2021  autoconf
# -rwxr-xr-x 1 root root        9034 Aug 23  2021  autoheader
# -rwxr-xr-x 1 root root       33475 Aug 23  2021  autom4te
# lrwxrwxrwx 1 root root          26 Apr 23 13:18  automake -> /etc/alternatives/automake
# -rwxr-xr-x 1 root root      262055 Mar 18  2022  automake-1.16
# -rwxr-xr-x 1 root root       26934 Aug 23  2021  autoreconf
# -rwxr-xr-x 1 root root       17177 Aug 23  2021  autoscan
# -rwxr-xr-x 1 root root       34017 Aug 23  2021  autoupdate
# lrwxrwxrwx 1 root root          21 Oct  4  2023  awk -> /etc/alternatives/awk
# -rwxr-xr-x 1 root root      258120 Mar 16  2022  b2
# -rwxr-xr-x 1 root root       51720 Feb  7  2022  b2sum
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  base32
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  base64
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  basename
# -rwxr-xr-x 1 root root       47616 Feb  7  2022  basenc
# -rwxr-xr-x 1 root root     1396520 Jan  6  2022  bash
# -rwxr-xr-x 1 root root        6818 Jan  6  2022  bashbug
# -rwxr-xr-x 1 root root       26888 Feb  6  2022  bcomps
# -rwxr-xr-x 1 root root      568304 Mar 16  2022  bcp
# lrwxrwxrwx 1 root root           2 Mar 16  2022  bjam -> b2
# -rwxr-xr-x 1 root root       72184 Nov 21 20:57  bootctl
# lrwxrwxrwx 1 root root           8 Aug 22  2022  browse -> xdg-open
# -rwxr-xr-x 3 root root       39296 Mar 23  2022  bunzip2
# -rwxr-xr-x 1 root root       92664 Nov 21 20:57  busctl
# -rwxr-xr-x 3 root root       39296 Mar 23  2022  bzcat
# lrwxrwxrwx 1 root root           6 Mar 23  2022  bzcmp -> bzdiff
# -rwxr-xr-x 1 root root        2225 Mar 23  2022  bzdiff
# lrwxrwxrwx 1 root root           6 Mar 23  2022  bzegrep -> bzgrep
# -rwxr-xr-x 1 root root        4893 Nov 27  2021  bzexe
# lrwxrwxrwx 1 root root           6 Mar 23  2022  bzfgrep -> bzgrep
# -rwxr-xr-x 1 root root        3775 Mar 23  2022  bzgrep
# -rwxr-xr-x 3 root root       39296 Mar 23  2022  bzip2
# -rwxr-xr-x 1 root root       14640 Mar 23  2022  bzip2recover
# lrwxrwxrwx 1 root root           6 Mar 23  2022  bzless -> bzmore
# -rwxr-xr-x 1 root root        1297 Mar 23  2022  bzmore
# lrwxrwxrwx 1 root root          21 Nov 10 05:10  c++ -> /etc/alternatives/c++
# lrwxrwxrwx 1 root root          21 Nov 10 05:10  c89 -> /etc/alternatives/c89
# -rwxr-xr-x 1 root root         428 Nov 17  2020  c89-gcc
# lrwxrwxrwx 1 root root          21 Nov 10 05:10  c99 -> /etc/alternatives/c99
# -rwxr-xr-x 1 root root         454 Nov 17  2020  c99-gcc
# lrwxrwxrwx 1 root root           3 May 16  2023  captoinfo -> tic
# -rwxr-xr-x 1 root root       35280 Feb  7  2022  cat
# -rwxr-xr-x 1 root root       35592 Mar 17  2022  catman
# lrwxrwxrwx 1 root root          20 Nov 10 05:10  cc -> /etc/alternatives/cc
# -rwxr-xr-x 1 root root       30984 Feb  6  2022  ccomps
# lrwxrwxrwx 1 root root          24 Jun  4  2023  c++filt -> x86_64-linux-gnu-c++filt
# -rwxr-sr-x 1 root shadow     72184 Nov 24  2022  chage
# -rwxr-xr-x 1 root root       14656 Jun  1  2022  chattr
# -rwxr-xr-x 1 root root       59904 Feb  7  2022  chcon
# -rwsr-xr-x 1 root root       72712 Nov 24  2022  chfn
# -rwxr-xr-x 1 root root       55808 Feb  7  2022  chgrp
# -rwxr-xr-x 1 root root       55808 Feb  7  2022  chmod
# -rwxr-xr-x 1 root root       22904 Feb 21  2022  choom
# -rwxr-xr-x 1 root root       59904 Feb  7  2022  chown
# -rwxr-xr-x 1 root root        2180 Nov 17  2021  chronic
# -rwxr-xr-x 1 root root       27000 Feb 21  2022  chrt
# -rwsr-xr-x 1 root root       44808 Nov 24  2022  chsh
# lrwxrwxrwx 1 root root           3 Feb  6  2022  circo -> dot
# -rwxr-xr-x 1 root root       35232 Feb  7  2022  cksum
# lrwxrwxrwx 1 root root          24 Apr  1  2022  clang -> ../lib/llvm-14/bin/clang
# lrwxrwxrwx 1 root root          26 Apr  1  2022  clang++ -> ../lib/llvm-14/bin/clang++
# lrwxrwxrwx 1 root root          26 Jul 14  2023  clang++-14 -> ../lib/llvm-14/bin/clang++
# lrwxrwxrwx 1 root root          24 Jul 14  2023  clang-14 -> ../lib/llvm-14/bin/clang
# lrwxrwxrwx 1 root root          28 Jul 14  2023  clang-cpp-14 -> ../lib/llvm-14/bin/clang-cpp
# -rwxr-xr-x 1 root root       14656 May 16  2023  clear
# -rwxr-xr-x 1 root root       14568 Jan  6  2022  clear_console
# -rwxr-xr-x 1 root root      140584 Feb 22  2021  clinfo
# -rwxr-xr-x 1 root root      606136 Feb  6  2022  cluster
# -rwxr-xr-x 1 root root     6747024 Feb  3 23:33  cmake
# -rwxr-xr-x 1 root root       43408 Mar 23  2022  cmp
# -rwxr-xr-x 1 root root       22920 Apr  9 15:32  col
# -rwxr-xr-x 1 root root       14728 Apr  9 15:32  colcrt
# -rwxr-xr-x 1 root root       14728 Apr  9 15:32  colrm
# -rwxr-xr-x 1 root root       35208 Apr  9 15:32  column
# -rwxr-xr-x 1 root root        3047 Nov 17  2021  combine
# -rwxr-xr-x 1 root root       35336 Feb  7  2022  comm
# -rwxr-xr-x 1 root root        1350 Jun  1  2022  compile_et
# -rwxr-xr-x 1 root root       15375 May 23  2023  corelist
# -rwxr-xr-x 1 root root      141824 Feb  7  2022  cp
# -rwxr-xr-x 1 root root     6685040 Feb  3 23:33  cpack
# -rwxr-xr-x 1 root root        8360 May 23  2023  cpan
# -rwxr-xr-x 1 root root        8381 May 23  2023  cpan5.34-x86_64-linux-gnu
# lrwxrwxrwx 1 root root           6 Aug  5  2021  cpp -> cpp-11
# lrwxrwxrwx 1 root root          23 May 13  2023  cpp-11 -> x86_64-linux-gnu-cpp-11
# lrwxrwxrwx 1 root root          23 Jul 11  2023  cpp-13 -> x86_64-linux-gnu-cpp-13
# -rwxr-xr-x 1 root root        6963 Oct 13  2023  c_rehash
# -rwxr-xr-x 1 root root      109056 Feb  7  2022  csplit
# -rwxr-xr-x 1 root root     7691024 Feb  3 23:33  ctest
# lrwxrwxrwx 1 root root           6 Mar 24  2022  ctstat -> lnstat
# -rwxr-xr-x 1 root root      260328 Mar 19 12:16  curl
# -rwxr-xr-x 1 root root        6675 Mar 19 12:16  curl-config
# -rwxr-xr-x 1 root root       39424 Feb  7  2022  cut
# -rwxr-xr-x 1 root root      303512 Apr  3  2023  cvtsudoers
# -rwxr-xr-x 1 root root      125688 Mar 23  2022  dash
# -rwxr-xr-x 1 root root      104960 Feb  7  2022  date
# -rwxr-xr-x 1 root root       14632 Oct 25  2022  dbus-cleanup-sockets
# -rwxr-xr-x 1 root root      232776 Oct 25  2022  dbus-daemon
# -rwxr-xr-x 1 root root       26920 Oct 25  2022  dbus-monitor
# -rwxr-xr-x 1 root root       14632 Oct 25  2022  dbus-run-session
# -rwxr-xr-x 1 root root       26920 Oct 25  2022  dbus-send
# -rwxr-xr-x 1 root root       14632 Oct 25  2022  dbus-update-activation-environment
# -rwxr-xr-x 1 root root       14632 Oct 25  2022  dbus-uuidgen
# -rwxr-xr-x 1 root root       68112 Feb  7  2022  dd
# -rwxr-xr-x 1 root root        2859 Feb 20  2022  debconf
# -rwxr-xr-x 1 root root       11541 Feb 20  2022  debconf-apt-progress
# -rwxr-xr-x 1 root root         608 Feb 20  2022  debconf-communicate
# -rwxr-xr-x 1 root root        1719 Feb 20  2022  debconf-copydb
# -rwxr-xr-x 1 root root         647 Feb 20  2022  debconf-escape
# -rwxr-xr-x 1 root root        2995 Feb 20  2022  debconf-set-selections
# -rwxr-xr-x 1 root root        1827 Feb 20  2022  debconf-show
# -rwxr-xr-x 1 root root       21394 Dec  7  2021  deb-systemd-helper
# -rwxr-xr-x 1 root root        6156 Feb 15  2022  deb-systemd-invoke
# -rwxr-xr-x 1 root root       14712 Feb 21  2022  delpart
# -rwxr-xr-x 1 root root       27520 Nov  4  2021  derb
# -rwxr-xr-x 1 root root       85064 Feb  7  2022  df
# -rwxr-xr-x 1 root root        1836 Jan 31  2022  dh_autotools-dev_restoreconfig
# -rwxr-xr-x 1 root root        1850 Jan 31  2022  dh_autotools-dev_updateconfig
# -rwxr-xr-x 1 root root      133680 Mar 23  2022  diff
# -rwxr-xr-x 1 root root       55824 Mar 23  2022  diff3
# -rwxr-xr-x 1 root root       18648 Feb  6  2022  diffimg
# -rwxr-xr-x 1 root root       22856 Feb  6  2022  dijkstra
# -rwxr-xr-x 1 root root      138208 Feb  7  2022  dir
# -rwxr-xr-x 1 root root       39432 Feb  7  2022  dircolors
# -rwxr-xr-x 1 root root      443408 Jul  4  2022  dirmngr
# -rwxr-xr-x 1 root root       56240 Jul  4  2022  dirmngr-client
# -rwxr-xr-x 1 root root       31104 Feb  7  2022  dirname
# -rwxr-xr-x 1 root root       72296 Feb 21  2022  dmesg
# lrwxrwxrwx 1 root root           8 Mar 23  2022  dnsdomainname -> hostname
# lrwxrwxrwx 1 root root           8 Mar 23  2022  domainname -> hostname
# lrwxrwxrwx 1 root root          29 Feb  6  2022  dot -> ../sbin/libgvc6-config-update
# lrwxrwxrwx 1 root root           6 Feb  6  2022  dot2gxl -> gxl2gv
# -rwxr-xr-x 1 root root       22872 Feb  6  2022  dot_builtins
# -rwxr-xr-x 1 root root        2085 Feb  6  2022  dotty
# -rwxr-xr-x 1 root root      318144 Apr  1  2023  dpkg
# -rwxr-xr-x 1 root root       13832 Apr  1  2023  dpkg-architecture
# -rwxr-xr-x 1 root root        7565 Apr  1  2023  dpkg-buildflags
# -rwxr-xr-x 1 root root       32425 Apr  1  2023  dpkg-buildpackage
# -rwxr-xr-x 1 root root        7624 Apr  1  2023  dpkg-checkbuilddeps
# -rwxr-xr-x 1 root root      137720 Apr  1  2023  dpkg-deb
# -rwxr-xr-x 1 root root        2782 Apr  1  2023  dpkg-distaddfile
# -rwxr-xr-x 1 root root      121336 Apr  1  2023  dpkg-divert
# -rwxr-xr-x 1 root root       17106 Apr  1  2023  dpkg-genbuildinfo
# -rwxr-xr-x 1 root root       17687 Apr  1  2023  dpkg-genchanges
# -rwxr-xr-x 1 root root       14580 Apr  1  2023  dpkg-gencontrol
# -rwxr-xr-x 1 root root       10902 Apr  1  2023  dpkg-gensymbols
# -rwxr-xr-x 1 root root       21209 Apr  1  2023  dpkg-maintscript-helper
# -rwxr-xr-x 1 root root        8903 Apr  1  2023  dpkg-mergechangelogs
# -rwxr-xr-x 1 root root        6789 Apr  1  2023  dpkg-name
# -rwxr-xr-x 1 root root        4947 Apr  1  2023  dpkg-parsechangelog
# -rwxr-xr-x 1 root root      141848 Apr  1  2023  dpkg-query
# -rwxr-xr-x 1 root root        4189 Apr  1  2023  dpkg-realpath
# -rwxr-xr-x 1 root root        8705 Apr  1  2023  dpkg-scanpackages
# -rwxr-xr-x 1 root root        9174 Apr  1  2023  dpkg-scansources
# -rwxr-xr-x 1 root root       31700 Apr  1  2023  dpkg-shlibdeps
# -rwxr-xr-x 1 root root       23106 Apr  1  2023  dpkg-source
# -rwxr-xr-x 1 root root      100872 Apr  1  2023  dpkg-split
# -rwxr-xr-x 1 root root       47368 Apr  1  2023  dpkg-statoverride
# -rwxr-xr-x 1 root root       43424 Apr  1  2023  dpkg-trigger
# -rwxr-xr-x 1 root root        3262 Apr  1  2023  dpkg-vendor
# -rwxr-xr-x 1 root root         837 Apr 10  2019  dtplite
# -rwxr-xr-x 1 root root      150016 Feb  7  2022  du
# lrwxrwxrwx 1 root root          20 Jun  4  2023  dwp -> x86_64-linux-gnu-dwp
# -rwxr-xr-x 1 root root       35120 Feb  7  2022  echo
# -rwxr-xr-x 1 root root      100696 Feb  6  2022  edgepaint
# lrwxrwxrwx 1 root root          24 Apr 23 13:15  editor -> /etc/alternatives/editor
# -rwxr-xr-x 1 root root          28 Mar 23  2022  egrep
# lrwxrwxrwx 1 root root          24 Jun  4  2023  elfedit -> x86_64-linux-gnu-elfedit
# -rwxr-xr-x 1 root root       41819 May 23  2023  enc2xs
# -rwxr-xr-x 1 root root        3078 May 23  2023  encguess
# -rwxr-xr-x 1 root root       43968 Feb  7  2022  env
# -rwxr-xr-x 1 root root      192968 Mar 23  2022  eqn
# -rwxr-xr-x 1 root root       22936 Nov 17  2021  errno
# lrwxrwxrwx 1 root root          20 Apr 23 13:15  ex -> /etc/alternatives/ex
# -rwxr-xr-x 1 root root       35352 Feb  7  2022  expand
# -rwxr-sr-x 1 root shadow     23136 Nov 24  2022  expiry
# -rwxr-xr-x 1 root root      108960 Feb  7  2022  expr
# lrwxrwxrwx 1 root root          21 Apr 23 13:15  f77 -> /etc/alternatives/f77
# lrwxrwxrwx 1 root root          21 Apr 23 13:15  f95 -> /etc/alternatives/f95
# -rwxr-xr-x 1 root root       72192 Feb  7  2022  factor
# -rwxr-xr-x 1 root root       23136 Nov 24  2022  faillog
# -rwxr-xr-x 1 root root       22904 Feb 21  2022  fallocate
# -rwxr-xr-x 1 root root       26928 Feb  7  2022  false
# -rwxr-xr-x 1 root root       22760 Mar 23  2022  fc-cache
# -rwxr-xr-x 1 root root       18664 Mar 23  2022  fc-cat
# -rwxr-xr-x 1 root root       14568 Mar 23  2022  fc-conflist
# -rwxr-xr-x 1 root root       14568 Mar 23  2022  fc-list
# -rwxr-xr-x 1 root root       14568 Mar 23  2022  fc-match
# -rwxr-xr-x 1 root root       14568 Mar 23  2022  fc-pattern
# -rwxr-xr-x 1 root root       14568 Mar 23  2022  fc-query
# -rwxr-xr-x 1 root root       14568 Mar 23  2022  fc-scan
# -rwxr-xr-x 1 root root       14568 Mar 23  2022  fc-validate
# lrwxrwxrwx 1 root root           3 Feb  6  2022  fdp -> dot
# -rwxr-xr-x 1 root root      301544 May 19  2022  ffmpeg
# -rwxr-xr-x 1 root root      149984 May 19  2022  ffplay
# -rwxr-xr-x 1 root root      178832 May 19  2022  ffprobe
# -rwxr-xr-x 1 root root          28 Mar 23  2022  fgrep
# -rwxr-xr-x 1 root root       27200 Sep 11  2023  file
# -rwxr-xr-x 1 root root        4529 Oct 31  2021  file-rename
# -rwxr-xr-x 1 root root       22952 Feb 21  2022  fincore
# -rwxr-xr-x 1 root root      282088 Mar 23  2022  find
# -rwxr-xr-x 1 root root       65128 Feb 21  2022  findmnt
# -rwxr-xr-x 1 root root     1795136 Oct 28  2021  fio
# -rwxr-xr-x 1 root root       22253 Oct 28  2021  fio2gnuplot
# -rwxr-xr-x 1 root root       31072 Oct 28  2021  fio-btrace2fio
# -rwxr-xr-x 1 root root       51672 Oct 28  2021  fio-dedupe
# -rwxr-xr-x 1 root root        4188 Oct 28  2021  fio_generate_plots
# -rwxr-xr-x 1 root root       31144 Oct 28  2021  fio-genzipf
# -rwxr-xr-x 1 root root       13227 Oct 28  2021  fio_jsonplus_clat2csv
# -rwxr-xr-x 1 root root       14640 Oct 28  2021  fio-verify-state
# -rwxr-xr-x 1 root root       23016 Feb 21  2022  flock
# -rwxr-xr-x 1 root root       39424 Feb  7  2022  fmt
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  fold
# -rwxr-xr-x 1 root root       26864 Feb 25  2022  free
# -rwxr-xr-x 1 root root       22832 Feb  1 15:52  funzip
# -rwxr-xr-x 1 root root       40256 Mar 24  2022  fuser
# -rwsr-xr-x 1 root root       39144 Mar 23  2022  fusermount
# lrwxrwxrwx 1 root root           6 Aug  5  2021  g++ -> g++-11
# lrwxrwxrwx 1 root root          23 May 13  2023  g++-11 -> x86_64-linux-gnu-g++-11
# lrwxrwxrwx 1 root root          23 Jul 11  2023  g++-13 -> x86_64-linux-gnu-g++-13
# -rwxr-xr-x 1 root root       22920 Jun  8  2023  gapplication
# -rwxr-xr-x 1 root root       22792 Feb  6  2022  gc
# lrwxrwxrwx 1 root root           6 Aug  5  2021  gcc -> gcc-11
# lrwxrwxrwx 1 root root          23 May 13  2023  gcc-11 -> x86_64-linux-gnu-gcc-11
# lrwxrwxrwx 1 root root          23 Jul 11  2023  gcc-13 -> x86_64-linux-gnu-gcc-13
# lrwxrwxrwx 1 root root           9 Aug  5  2021  gcc-ar -> gcc-ar-11
# lrwxrwxrwx 1 root root          26 May 13  2023  gcc-ar-11 -> x86_64-linux-gnu-gcc-ar-11
# lrwxrwxrwx 1 root root          26 Jul 11  2023  gcc-ar-13 -> x86_64-linux-gnu-gcc-ar-13
# lrwxrwxrwx 1 root root           9 Aug  5  2021  gcc-nm -> gcc-nm-11
# lrwxrwxrwx 1 root root          26 May 13  2023  gcc-nm-11 -> x86_64-linux-gnu-gcc-nm-11
# lrwxrwxrwx 1 root root          26 Jul 11  2023  gcc-nm-13 -> x86_64-linux-gnu-gcc-nm-13
# lrwxrwxrwx 1 root root          13 Aug  5  2021  gcc-ranlib -> gcc-ranlib-11
# lrwxrwxrwx 1 root root          30 May 13  2023  gcc-ranlib-11 -> x86_64-linux-gnu-gcc-ranlib-11
# lrwxrwxrwx 1 root root          30 Jul 11  2023  gcc-ranlib-13 -> x86_64-linux-gnu-gcc-ranlib-13
# lrwxrwxrwx 1 root root           7 Aug  5  2021  gcov -> gcov-11
# lrwxrwxrwx 1 root root          24 May 13  2023  gcov-11 -> x86_64-linux-gnu-gcov-11
# lrwxrwxrwx 1 root root          24 Jul 11  2023  gcov-13 -> x86_64-linux-gnu-gcov-13
# lrwxrwxrwx 1 root root          12 Aug  5  2021  gcov-dump -> gcov-dump-11
# lrwxrwxrwx 1 root root          29 May 13  2023  gcov-dump-11 -> x86_64-linux-gnu-gcov-dump-11
# lrwxrwxrwx 1 root root          29 Jul 11  2023  gcov-dump-13 -> x86_64-linux-gnu-gcov-dump-13
# lrwxrwxrwx 1 root root          12 Aug  5  2021  gcov-tool -> gcov-tool-11
# lrwxrwxrwx 1 root root          29 May 13  2023  gcov-tool-11 -> x86_64-linux-gnu-gcov-tool-11
# lrwxrwxrwx 1 root root          29 Jul 11  2023  gcov-tool-13 -> x86_64-linux-gnu-gcov-tool-13
# -rwxr-xr-x 1 root root        2306 Apr 23  2023  gdal-config
# -rwxr-xr-x 1 root root       51592 Jun  8  2023  gdbus
# -rwxr-xr-x 1 root root       15136 Nov  4  2021  genbrk
# -rwxr-xr-x 1 root root       27000 Apr 16 13:40  gencat
# -rwxr-xr-x 1 root root       15080 Nov  4  2021  gencfu
# -rwxr-xr-x 1 root root       27248 Nov  4  2021  gencnval
# -rwxr-xr-x 1 root root       27424 Nov  4  2021  gendict
# -rwxr-xr-x 1 root root        8753 Oct 28  2021  genfio
# -rwxr-xr-x 1 root root      151464 Nov  4  2021  genrb
# -rwxr-xr-x 1 root root        1190 Dec  5  2022  geos-config
# lrwxrwxrwx 1 root root           3 Mar 23  2022  geqn -> eqn
# -rwxr-xr-x 1 root root       35112 Sep 25  2023  getconf
# -rwxr-xr-x 1 root root       39576 Sep 25  2023  getent
# -rwxr-xr-x 1 root root       22904 Feb 21  2022  getopt
# lrwxrwxrwx 1 root root          11 Aug  5  2021  gfortran -> gfortran-11
# lrwxrwxrwx 1 root root          28 May 13  2023  gfortran-11 -> x86_64-linux-gnu-gfortran-11
# -rwxr-xr-x 1 root root       92568 Jun  8  2023  gio
# lrwxrwxrwx 1 root root          49 Jun  8  2023  gio-querymodules -> ../lib/x86_64-linux-gnu/glib-2.0/gio-querymodules
# -rwxr-xr-x 1 root root     3702168 Jul  7  2023  git
# -rwxr-xr-x 1 root root    10312624 May  1  2023  git-lfs
# lrwxrwxrwx 1 root root           3 Jul  7  2023  git-receive-pack -> git
# -rwxr-xr-x 1 root root      565840 Jul  7  2023  git-shell
# lrwxrwxrwx 1 root root           3 Jul  7  2023  git-upload-archive -> git
# lrwxrwxrwx 1 root root           3 Jul  7  2023  git-upload-pack -> git
# lrwxrwxrwx 1 root root          53 Jun  8  2023  glib-compile-schemas -> ../lib/x86_64-linux-gnu/glib-2.0/glib-compile-schemas
# lrwxrwxrwx 1 root root           4 Feb 15  2022  gmake -> make
# -rwxr-xr-x 1 root root       51696 Feb  6  2022  gml2gv
# lrwxrwxrwx 1 root root          21 Jun  4  2023  gold -> x86_64-linux-gnu-gold
# -rwxr-xr-x 1 root root      178252 Mar 23  2022  google-pprof
# -rwsr-xr-x 1 root root       72072 Nov 24  2022  gpasswd
# -rwxr-xr-x 1 root root     1050624 Jul  4  2022  gpg
# lrwxrwxrwx 1 root root           3 Jul  4  2022  gpg2 -> gpg
# -rwxr-xr-x 1 root root      320472 Jul  4  2022  gpg-agent
# -rwxr-xr-x 1 root root      508400 Jul  4  2022  gpgcompose
# -rwxr-xr-x 1 root root      129776 Jul  4  2022  gpgconf
# -rwxr-xr-x 1 root root       84984 Jul  4  2022  gpg-connect-agent
# -rwxr-xr-x 1 root root       35200 Jul  4  2022  gpgparsemail
# -rwxr-xr-x 1 root root      428952 Jul  4  2022  gpgsm
# -rwxr-xr-x 1 root root       27184 Jul  4  2022  gpgsplit
# -rwxr-xr-x 1 root root       64912 Jul  4  2022  gpgtar
# -rwxr-xr-x 1 root root      277544 Jul  4  2022  gpgv
# -rwxr-xr-x 1 root root      117816 Jul  4  2022  gpg-wks-server
# -rwxr-xr-x 1 root root        3516 Jul  4  2022  gpg-zip
# lrwxrwxrwx 1 root root           3 Mar 23  2022  gpic -> pic
# lrwxrwxrwx 1 root root          22 Jun  4  2023  gprof -> x86_64-linux-gnu-gprof
# -rwxr-xr-x 1 root root       31048 Feb  6  2022  graphml2gv
# -rwxr-xr-x 1 root root      182728 Mar 23  2022  grep
# -rwxr-xr-x 1 root root       22840 Jun  8  2023  gresource
# -rwxr-xr-x 1 root root       96768 Mar 23  2022  groff
# -rwxr-xr-x 1 root root        2776 Mar 23  2022  grog
# -rwxr-xr-x 1 root root      166456 Mar 23  2022  grops
# -rwxr-xr-x 1 root root      121368 Mar 23  2022  grotty
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  groups
# -rwxr-xr-x 1 root root       31032 Jun  8  2023  gsettings
# lrwxrwxrwx 1 root root           3 Mar 23  2022  gtbl -> tbl
# -rwxr-xr-x 1 root root       39496 May  9  2022  gtk-update-icon-cache
# -rwxr-xr-x 2 root root        2346 Sep  5  2022  gunzip
# -rwxr-xr-x 1 root root       26888 Feb  6  2022  gv2gml
# lrwxrwxrwx 1 root root           6 Feb  6  2022  gv2gxl -> gxl2gv
# -rwxr-xr-x 1 root root       53736 Feb  6  2022  gvcolor
# -rwxr-xr-x 1 root root       26848 Feb  6  2022  gvgen
# -rwxr-xr-x 1 root root      610232 Feb  6  2022  gvmap
# -rwxr-xr-x 1 root root        2181 Feb  6  2022  gvmap.sh
# -rwxr-xr-x 1 root root       31176 Feb  6  2022  gvpack
# -rwxr-xr-x 1 root root       18648 Feb  6  2022  gvpr
# lrwxrwxrwx 1 root root           6 Feb  6  2022  gxl2dot -> gxl2gv
# -rwxr-xr-x 1 root root       47560 Feb  6  2022  gxl2gv
# -rwxr-xr-x 1 root root        6447 Sep  5  2022  gzexe
# -rwxr-xr-x 1 root root       93424 Sep  5  2022  gzip
# -rwxr-xr-x 1 root root       29227 May 23  2023  h2ph
# -rwxr-xr-x 1 root root       60934 May 23  2023  h2xs
# -rwxr-xr-x 1 root root       13050 Dec  8  2021  h5c++
# -rwxr-xr-x 1 root root       12876 Dec  8  2021  h5cc
# -rwxr-xr-x 1 root root       12694 Dec  8  2021  h5fc
# -rwxr-xr-x 1 root root       35248 Feb 21  2022  hardlink
# lrwxrwxrwx 1 root root           7 Apr  9 15:32  hd -> hexdump
# -rwxr-xr-x 1 root root       43520 Feb  7  2022  head
# -rwxr-xr-x 1 root root        2514 Jan  3  2022  helpztags
# -rwxr-xr-x 1 root root       51600 Apr  9 15:32  hexdump
# -rwxr-xr-x 1 root root       31232 Feb  7  2022  hostid
# -rwxr-xr-x 1 root root       22760 Mar 23  2022  hostname
# -rwxr-xr-x 1 root root       31104 Nov 21 20:57  hostnamectl
# lrwxrwxrwx 1 root root           7 Feb 21  2022  i386 -> setarch
# -rwxr-xr-x 1 root root       68000 Sep 25  2023  iconv
# -rwxr-xr-x 1 root root       31728 Nov  4  2021  icuexportdata
# -rwxr-xr-x 1 root root       14968 Nov  4  2021  icuinfo
# -rwxr-xr-x 1 root root       39424 Feb  7  2022  id
# -rwxr-xr-x 1 root root       23048 Nov 17  2021  ifdata
# -rwxr-xr-x 1 root root        4183 Aug 23  2021  ifnames
# -rwxr-xr-x 1 root root       14488 Nov 17  2021  ifne
# -rwxr-xr-x 1 root root       63872 May 16  2023  infocmp
# lrwxrwxrwx 1 root root           3 May 16  2023  infotocap -> tic
# -rwxr-xr-x 1 root root      404912 Mar 16  2022  inspect
# -rwxr-xr-x 1 root root      145936 Feb  7  2022  install
# -rwxr-xr-x 1 root root        4373 May 23  2023  instmodsh
# -rwxr-xr-x 1 root root       18808 Feb 21  2022  ionice
# -rwxr-xr-x 1 root root      718896 Mar 24  2022  ip
# -rwxr-xr-x 1 root root       22976 Feb 21  2022  ipcmk
# -rwxr-xr-x 1 root root       18808 Feb 21  2022  ipcrm
# -rwxr-xr-x 1 root root       39288 Feb 21  2022  ipcs
# -rwxr-xr-x 1 root root       14536 Mar 23  2022  ischroot
# -rwxr-xr-x 1 root root       14488 Nov 17  2021  isutf8
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  jaotc -> /etc/alternatives/jaotc
# lrwxrwxrwx 1 root root          21 Apr 23 13:18  jar -> /etc/alternatives/jar
# lrwxrwxrwx 1 root root          27 Apr 23 13:18  jarsigner -> /etc/alternatives/jarsigner
# lrwxrwxrwx 1 root root          22 Apr 23 13:18  java -> /etc/alternatives/java
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  javac -> /etc/alternatives/javac
# lrwxrwxrwx 1 root root          25 Apr 23 13:18  javadoc -> /etc/alternatives/javadoc
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  javap -> /etc/alternatives/javap
# lrwxrwxrwx 1 root root          22 Apr 23 13:18  jcmd -> /etc/alternatives/jcmd
# lrwxrwxrwx 1 root root          21 Apr 23 13:18  jdb -> /etc/alternatives/jdb
# lrwxrwxrwx 1 root root          27 Apr 23 13:18  jdeprscan -> /etc/alternatives/jdeprscan
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  jdeps -> /etc/alternatives/jdeps
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  jexec -> /etc/alternatives/jexec
# lrwxrwxrwx 1 root root          21 Apr 23 13:18  jfr -> /etc/alternatives/jfr
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  jhsdb -> /etc/alternatives/jhsdb
# lrwxrwxrwx 1 root root          24 Apr 23 13:18  jimage -> /etc/alternatives/jimage
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  jinfo -> /etc/alternatives/jinfo
# lrwxrwxrwx 1 root root          21 Apr 23 13:18  jjs -> /etc/alternatives/jjs
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  jlink -> /etc/alternatives/jlink
# lrwxrwxrwx 1 root root          22 Apr 23 13:18  jmap -> /etc/alternatives/jmap
# lrwxrwxrwx 1 root root          22 Apr 23 13:18  jmod -> /etc/alternatives/jmod
# -rwxr-xr-x 1 root root       47656 Feb  7  2022  join
# -rwxr-xr-x 1 root root       80272 Nov 21 20:57  journalctl
# lrwxrwxrwx 1 root root          21 Apr 23 13:18  jps -> /etc/alternatives/jps
# lrwxrwxrwx 1 root root          28 Apr 23 13:18  jrunscript -> /etc/alternatives/jrunscript
# lrwxrwxrwx 1 root root          24 Apr 23 13:18  jshell -> /etc/alternatives/jshell
# -rwxr-xr-x 1 root root        4992 May 23  2023  json_pp
# lrwxrwxrwx 1 root root          24 Apr 23 13:18  jstack -> /etc/alternatives/jstack
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  jstat -> /etc/alternatives/jstat
# lrwxrwxrwx 1 root root          24 Apr 23 13:18  jstatd -> /etc/alternatives/jstatd
# -rwxr-xr-x 1 root root       64336 Jul  4  2022  kbxutil
# -rwxr-xr-x 1 root root        4902 Mar 11  2022  kernel-install
# -rwxr-xr-x 1 root root         961 Jan  2  2022  keyring
# lrwxrwxrwx 1 root root          25 Apr 23 13:18  keytool -> /etc/alternatives/keytool
# -rwxr-xr-x 1 root root       30952 Feb 25  2022  kill
# -rwxr-xr-x 1 root root       32096 Mar 24  2022  killall
# -rwxr-xr-x 1 root root      170352 Aug 17  2021  kmod
# lrwxrwxrwx 1 root root          15 Oct 24  2023  krb5-config -> krb5-config.mit
# -rwxr-xr-x 1 root root        6941 Oct 24  2023  krb5-config.mit
# -rwxr-xr-x 1 root root       35192 Feb 21  2022  last
# lrwxrwxrwx 1 root root           4 Feb 21  2022  lastb -> last
# -rwxr-xr-x 1 root root       28288 Nov 24  2022  lastlog
# -rwxr-xr-x 1 root root        7784 Jun 16  2020  lcf
# -rwxr-xr-x 1 root root       14488 Nov 17  2021  lckdo
# lrwxrwxrwx 1 root root          19 Jun  4  2023  ld -> x86_64-linux-gnu-ld
# lrwxrwxrwx 1 root root          23 Jun  4  2023  ld.bfd -> x86_64-linux-gnu-ld.bfd
# -rwxr-xr-x 1 root root        5443 Sep 25  2023  ldd
# lrwxrwxrwx 1 root root          24 Jun  4  2023  ld.gold -> x86_64-linux-gnu-ld.gold
# -rwxr-xr-x 1 root root      295256 Feb  6  2022  lefty
# -rwxr-xr-x 1 root root      199048 Feb 20 13:07  less
# -rwxr-xr-x 1 root root       14656 Feb 20 13:07  lessecho
# lrwxrwxrwx 1 root root           8 Feb 20 13:07  lessfile -> lesspipe
# -rwxr-xr-x 1 root root       24272 Feb 20 13:07  lesskey
# -rwxr-xr-x 1 root root        9047 Dec 28  2021  lesspipe
# -rwxr-xr-x 1 root root      102144 Mar 17  2022  lexgrog
# -rwxr-xr-x 1 root root       15778 May 23  2023  libnetcfg
# -rwxr-xr-x 1 root root        2471 Mar 24  2022  libpng16-config
# lrwxrwxrwx 1 root root          15 Mar 24  2022  libpng-config -> libpng16-config
# -rwxr-xr-x 1 root root       31232 Feb  7  2022  link
# lrwxrwxrwx 1 root root           7 Feb 21  2022  linux32 -> setarch
# lrwxrwxrwx 1 root root           7 Feb 21  2022  linux64 -> setarch
# -rwxr-xr-x 1 root root       59904 Feb  7  2022  ln
# -rwxr-xr-x 1 root root        1547 Feb  6  2022  lneato
# -rwxr-xr-x 1 root root       23200 Mar 24  2022  lnstat
# -rwxr-xr-x 1 root root       58944 Sep 25  2023  locale
# -rwxr-xr-x 1 root root       14488 Aug  2  2023  locale-check
# -rwxr-xr-x 1 root root       27000 Nov 21 20:57  localectl
# -rwxr-xr-x 1 root root      334808 Sep 25  2023  localedef
# -rwxr-xr-x 1 root root       35800 Feb 21  2022  logger
# -rwxr-xr-x 1 root root       52976 Nov 24  2022  login
# -rwxr-xr-x 1 root root       59888 Nov 21 20:57  loginctl
# -rwxr-xr-x 1 root root       31232 Feb  7  2022  logname
# -rwxr-xr-x 1 root root       18824 Apr  9 15:32  look
# -rwxr-xr-x 1 root root      138208 Feb  7  2022  ls
# -rwxr-xr-x 1 root root       14656 Jun  1  2022  lsattr
# -rwxr-xr-x 1 root root      125312 Feb 21  2022  lsblk
# -rwxr-xr-x 1 root root        3638 Aug 25  2019  lsb_release
# -rwxr-xr-x 1 root root      100728 Feb 21  2022  lscpu
# -rwxr-xr-x 1 root root       51576 Feb 21  2022  lsipc
# -rwxr-xr-x 1 root root       31432 Feb 21  2022  lslocks
# -rwxr-xr-x 1 root root       51576 Feb 21  2022  lslogins
# -rwxr-xr-x 1 root root       39288 Feb 21  2022  lsmem
# lrwxrwxrwx 1 root root           4 Aug 17  2021  lsmod -> kmod
# -rwxr-xr-x 1 root root       39296 Feb 21  2022  lsns
# -rwxr-xr-x 1 root root      167544 Mar 24  2022  lsof
# -rwxr-xr-x 1 root root        1081 Aug 28  2017  lspgpot
# lrwxrwxrwx 1 root root          28 May 13  2023  lto-dump-11 -> x86_64-linux-gnu-lto-dump-11
# lrwxrwxrwx 1 root root          28 Jul 11  2023  lto-dump-13 -> x86_64-linux-gnu-lto-dump-13
# lrwxrwxrwx 1 root root          23 Nov 10 05:10  lzcat -> /etc/alternatives/lzcat
# lrwxrwxrwx 1 root root          23 Nov 10 05:10  lzcmp -> /etc/alternatives/lzcmp
# lrwxrwxrwx 1 root root          24 Nov 10 05:10  lzdiff -> /etc/alternatives/lzdiff
# lrwxrwxrwx 1 root root          25 Nov 10 05:10  lzegrep -> /etc/alternatives/lzegrep
# lrwxrwxrwx 1 root root          25 Nov 10 05:10  lzfgrep -> /etc/alternatives/lzfgrep
# lrwxrwxrwx 1 root root          24 Nov 10 05:10  lzgrep -> /etc/alternatives/lzgrep
# lrwxrwxrwx 1 root root          24 Nov 10 05:10  lzless -> /etc/alternatives/lzless
# lrwxrwxrwx 1 root root          22 Nov 10 05:10  lzma -> /etc/alternatives/lzma
# -rwxr-xr-x 1 root root       14568 Apr  8  2022  lzmainfo
# lrwxrwxrwx 1 root root          24 Nov 10 05:10  lzmore -> /etc/alternatives/lzmore
# -rwxr-xr-x 1 root root      158072 Mar 24  2022  m4
# -rwxr-xr-x 1 root root      255696 Feb 15  2022  make
# -rwxr-xr-x 1 root root       52112 Nov  4  2021  makeconv
# -rwxr-xr-x 1 root root        4905 Feb 15  2022  make-first-existing-target
# -rwxr-xr-x 1 root root         320 Oct  4  2023  man
# -rwxr-xr-x 1 root root      143296 Mar 17  2022  mandb
# -rwxr-xr-x 1 root root       31520 Mar 17  2022  manpath
# -rwxr-xr-x 1 root root      120504 Mar 17  2022  man.REAL
# -rwxr-xr-x 1 root root       36536 Mar 17  2022  man-recode
# -rwxr-xr-x 1 root root      158504 Jan 23  2022  mawk
# -rwxr-xr-x 1 root root       27072 Feb 21  2022  mcookie
# -rwxr-xr-x 1 root root       43424 Feb  7  2022  md5sum
# lrwxrwxrwx 1 root root           6 Feb  7  2022  md5sum.textutils -> md5sum
# -rwxr-xr-x 1 root root       14712 Feb 21  2022  mesg
# -rwxr-xr-x 1 root root        3060 Dec 18  2021  migrate-pubring-from-classic-gpg
# -rwxr-xr-x 1 root root       80304 Feb  6  2022  mingle
# -rwxr-xr-x 1 root root       14488 Nov 17  2021  mispipe
# -rwxr-xr-x 1 root root       68096 Feb  7  2022  mkdir
# -rwxr-xr-x 1 root root       39424 Feb  7  2022  mkfifo
# -rwxr-xr-x 1 root root       43520 Feb  7  2022  mknod
# -rwxr-xr-x 1 root root       39424 Feb  7  2022  mktemp
# -rwxr-xr-x 1 root root       35112 Feb  6  2022  mm2gv
# -rwxr-xr-x 1 root root       43392 Feb 21  2022  more
# -rwsr-xr-x 1 root root       47480 Feb 21  2022  mount
# -rwxr-xr-x 1 root root       18808 Feb 21  2022  mountpoint
# -rwxr-xr-x 1 root root        3210 Apr 10  2019  mpexpand
# lrwxrwxrwx 1 root root          24 Apr 23 13:18  mpic++ -> /etc/alternatives/mpic++
# lrwxrwxrwx 1 root root          21 Apr 23 13:18  mpicc -> /etc/alternatives/mpi
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  mpiCC -> /etc/alternatives/mpiCC
# lrwxrwxrwx 1 root root          12 Mar  4  2022  mpicc.openmpi -> opal_wrapper
# lrwxrwxrwx 1 root root          12 Mar  4  2022  mpiCC.openmpi -> opal_wrapper
# lrwxrwxrwx 1 root root          12 Mar  4  2022  mpic++.openmpi -> opal_wrapper
# lrwxrwxrwx 1 root root          24 Apr 23 13:18  mpicxx -> /etc/alternatives/mpicxx
# lrwxrwxrwx 1 root root          12 Mar  4  2022  mpicxx.openmpi -> opal_wrapper
# lrwxrwxrwx 1 root root          25 Apr 23 13:18  mpiexec -> /etc/alternatives/mpiexec
# lrwxrwxrwx 1 root root           7 Mar  4  2022  mpiexec.openmpi -> orterun
# lrwxrwxrwx 1 root root          24 Apr 23 13:18  mpif77 -> /etc/alternatives/mpif77
# lrwxrwxrwx 1 root root          12 Mar  4  2022  mpif77.openmpi -> opal_wrapper
# lrwxrwxrwx 1 root root          24 Apr 23 13:18  mpif90 -> /etc/alternatives/mpif90
# lrwxrwxrwx 1 root root          12 Mar  4  2022  mpif90.openmpi -> opal_wrapper
# lrwxrwxrwx 1 root root          25 Apr 23 13:18  mpifort -> /etc/alternatives/mpifort
# lrwxrwxrwx 1 root root          12 Mar  4  2022  mpifort.openmpi -> opal_wrapper
# lrwxrwxrwx 1 root root          11 Mar  4  2022  mpijavac -> mpijavac.pl
# -rwxr-xr-x 1 root root        4816 Mar  4  2022  mpijavac.pl
# lrwxrwxrwx 1 root root          24 Apr 23 13:18  mpirun -> /etc/alternatives/mpirun
# lrwxrwxrwx 1 root root           7 Mar  4  2022  mpirun.openmpi -> orterun
# -rwxr-xr-x 1 root root      137744 Feb  7  2022  mv
# -rwxr-xr-x 1 root root        5040 Jan 17 20:13  mysql_config
# -rwxr-xr-x 1 root root       22904 Feb 21  2022  namei
# lrwxrwxrwx 1 root root          22 Oct  4  2023  nawk -> /etc/alternatives/nawk
# -rwxr-xr-x 1 root root        9446 Sep 29  2021  nc-config
# lrwxrwxrwx 1 root root          15 May 16  2023  ncurses5-config -> ncurses6-config
# -rwxr-xr-x 1 root root        8402 May 16  2023  ncurses6-config
# lrwxrwxrwx 1 root root          16 May 16  2023  ncursesw5-config -> ncursesw6-config
# -rwxr-xr-x 1 root root        8405 May 16  2023  ncursesw6-config
# lrwxrwxrwx 1 root root           3 Feb  6  2022  neato -> dot
# -rwxr-xr-x 1 root root         913 Mar 23  2022  neqn
# -rwxr-xr-x 1 root root      104832 Nov 21 20:57  networkctl
# -rwsr-xr-x 1 root root       40496 Nov 24  2022  newgrp
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  nice
# lrwxrwxrwx 1 root root           8 Mar 23  2022  nisdomainname -> hostname
# -rwxr-xr-x 1 root root      100928 Feb  7  2022  nl
# lrwxrwxrwx 1 root root          19 Jun  4  2023  nm -> x86_64-linux-gnu-nm
# -rwxr-xr-x 1 root root        7234 Apr 10  2019  nns
# -rwxr-xr-x 1 root root        3373 Apr 10  2019  nnsd
# -rwxr-xr-x 1 root root        4485 Apr 10  2019  nnslog
# -rwxr-xr-x 1 root root       35232 Feb  7  2022  nohup
# -rwxr-xr-x 1 root root       18696 Feb  6  2022  nop
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  nproc
# -rwxr-xr-x 1 root root        3293 Mar 23  2022  nroff
# -rwxr-xr-x 1 root root       27232 Feb 21  2022  nsenter
# -rwxr-xr-x 1 root root       31104 Mar 24  2022  nstat
# -rwxr-xr-x 1 root root       55840 Feb  7  2022  numfmt
# lrwxrwxrwx 1 root root          37 Apr 24 19:53  nvidia-bug-report.sh -> /opt/bin/.nvidia/nvidia-bug-report.sh
# lrwxrwxrwx 1 root root          40 Apr 24 19:53  nvidia-cuda-mps-control -> /opt/bin/.nvidia/nvidia-cuda-mps-control
# lrwxrwxrwx 1 root root          39 Apr 24 19:53  nvidia-cuda-mps-server -> /opt/bin/.nvidia/nvidia-cuda-mps-server
# lrwxrwxrwx 1 root root          33 Apr 24 19:53  nvidia-debugdump -> /opt/bin/.nvidia/nvidia-debugdump
# lrwxrwxrwx 1 root root          33 Apr 24 19:53  nvidia-installer -> /opt/bin/.nvidia/nvidia-installer
# lrwxrwxrwx 1 root root          32 Apr 24 19:53  nvidia-modprobe -> /opt/bin/.nvidia/nvidia-modprobe
# lrwxrwxrwx 1 root root          35 Apr 24 19:53  nvidia-ngx-updater -> /opt/bin/.nvidia/nvidia-ngx-updater
# lrwxrwxrwx 1 root root          36 Apr 24 19:53  nvidia-persistenced -> /opt/bin/.nvidia/nvidia-persistenced
# lrwxrwxrwx 1 root root          30 Apr 24 19:53  nvidia-powerd -> /opt/bin/.nvidia/nvidia-powerd
# lrwxrwxrwx 1 root root          32 Apr 24 19:53  nvidia-settings -> /opt/bin/.nvidia/nvidia-settings
# lrwxrwxrwx 1 root root          32 Apr 24 19:53  nvidia-sleep.sh -> /opt/bin/.nvidia/nvidia-sleep.sh
# lrwxrwxrwx 1 root root          27 Apr 24 19:53  nvidia-smi -> /opt/bin/.nvidia/nvidia-smi
# lrwxrwxrwx 1 root root          33 Apr 24 19:53  nvidia-uninstall -> /opt/bin/.nvidia/nvidia-uninstall
# lrwxrwxrwx 1 root root          31 Apr 24 19:53  nvidia-xconfig -> /opt/bin/.nvidia/nvidia-xconfig
# lrwxrwxrwx 1 root root           2 Mar 22  2020  nvptx-none-ar -> ar
# -rwxr-xr-x 1 root root       47616 Mar 22  2020  nvptx-none-as
# -rwxr-xr-x 1 root root       35160 Mar 22  2020  nvptx-none-ld
# lrwxrwxrwx 1 root root           6 Mar 22  2020  nvptx-none-ranlib -> ranlib
# lrwxrwxrwx 1 root root          24 Jun  4  2023  objcopy -> x86_64-linux-gnu-objcopy
# lrwxrwxrwx 1 root root          24 Jun  4  2023  objdump -> x86_64-linux-gnu-objdump
# -rwxr-xr-x 1 root root       68096 Feb  7  2022  od
# -rwxr-xr-x 1 root root        2200 Jun 14  2021  ogdi-config
# lrwxrwxrwx 1 root root          10 Mar  4  2022  ompi-clean -> orte-clean
# -rwxr-xr-x 1 root root       31032 Mar  4  2022  ompi_info
# lrwxrwxrwx 1 root root          11 Mar  4  2022  ompi-server -> orte-server
# lrwxrwxrwx 1 root root          12 Mar  4  2022  opalc++ -> opal_wrapper
# lrwxrwxrwx 1 root root          12 Mar  4  2022  opalcc -> opal_wrapper
# -rwxr-xr-x 1 root root       26944 Mar  4  2022  opal_wrapper
# lrwxrwxrwx 1 root root          22 Apr 23 13:15  open -> /etc/alternatives/open
# -rwxr-xr-x 1 root root       27024 Dec  5  2022  opencv_annotation
# -rwxr-xr-x 1 root root      109032 Dec  5  2022  opencv_interactive-calibration
# -rwxr-xr-x 1 root root       18824 Dec  5  2022  opencv_model_diagnostics
# -rwxr-xr-x 1 root root       31200 Dec  5  2022  opencv_version
# -rwxr-xr-x 1 root root       47584 Dec  5  2022  opencv_visualisation
# -rwxr-xr-x 1 root root       18824 Dec  5  2022  opencv_waldboost_detector
# -rwxr-xr-x 1 root root     1001272 Oct 13  2023  openssl
# lrwxrwxrwx 1 root root          12 Mar  4  2022  ortecc -> opal_wrapper
# -rwxr-xr-x 1 root root       14952 Mar  4  2022  orte-clean
# -rwxr-xr-x 1 root root       14648 Mar  4  2022  orted
# -rwxr-xr-x 1 root root       35128 Mar  4  2022  orte-info
# -rwxr-xr-x 1 root root       14648 Mar  4  2022  orterun
# -rwxr-xr-x 1 root root       19120 Mar  4  2022  orte-server
# lrwxrwxrwx 1 root root           3 Feb  6  2022  osage -> dot
# lrwxrwxrwx 1 root root          12 Mar  4  2022  oshc++ -> opal_wrapper
# lrwxrwxrwx 1 root root          12 Mar  4  2022  oshcc -> opal_wrapper
# lrwxrwxrwx 1 root root          12 Mar  4  2022  oshCC -> opal_wrapper
# lrwxrwxrwx 1 root root          12 Mar  4  2022  oshcxx -> opal_wrapper
# lrwxrwxrwx 1 root root          12 Mar  4  2022  oshfort -> opal_wrapper
# -rwxr-xr-x 1 root root       31032 Mar  4  2022  oshmem_info
# lrwxrwxrwx 1 root root          14 Mar  4  2022  oshrun -> mpirun.openmpi
# -rwxr-xr-x 1 root root        4754 Aug 15  2020  p7zip
# lrwxrwxrwx 1 root root          25 Apr 23 13:18  pack200 -> /etc/alternatives/pack200
# -rwxr-xr-x 1 root root       19490 Apr 10  2019  page
# lrwxrwxrwx 1 root root          23 Oct  4  2023  pager -> /etc/alternatives/pager
# -rwxr-xr-x 1 root root   154951720 Mar 21  2022  pandoc
# -rwxr-xr-x 1 root root       14488 Mar 24  2022  paperconf
# -rwxr-xr-x 1 root root       14488 Nov 17  2021  parallel
# -rwxr-xr-x 1 root root       59776 Feb 21  2022  partx
# -rwsr-xr-x 1 root root       59976 Nov 24  2022  passwd
# -rwxr-xr-x 1 root root       35232 Feb  7  2022  paste
# -rwxr-xr-x 1 root root      190992 Mar 24  2022  patch
# lrwxrwxrwx 1 root root           3 Feb  6  2022  patchwork -> dot
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  pathchk
# -rwxr-xr-x 1 root root        1976 Sep 20  2022  pcre2-config
# -rwxr-xr-x 1 root root        2341 May 17  2022  pcre-config
# lrwxrwxrwx 1 root root           7 Aug 18  2022  pdb3 -> pdb3.10
# lrwxrwxrwx 1 root root          24 Nov 20 15:14  pdb3.10 -> ../lib/python3.10/pdb.py
# -rwxr-xr-x 1 root root       14488 Nov 17  2021  pee
# -rwxr-xr-x 1 root root       14640 Mar 24  2022  peekfd
# -rwxr-xr-x 2 root root     3798008 May 23  2023  perl
# -rwxr-xr-x 2 root root     3798008 May 23  2023  perl5.34.0
# -rwxr-xr-x 1 root root       14648 May 23  2023  perl5.34-x86_64-linux-gnu
# -rwxr-xr-x 2 root root       45183 May 23  2023  perlbug
# -rwxr-xr-x 1 root root         125 Aug 25  2021  perldoc
# -rwxr-xr-x 1 root root       10867 May 23  2023  perlivp
# -rwxr-xr-x 2 root root       45183 May 23  2023  perlthanks
# -rwxr-xr-x 1 root root        6709 Feb 10 00:49  pg_config
# -rwxr-xr-x 1 root root       30968 Feb 25  2022  pgrep
# -rwxr-xr-x 1 root root      204840 Mar 23  2022  pic
# -rwxr-xr-x 1 root root        8360 May 23  2023  piconv
# lrwxrwxrwx 1 root root          14 Dec 14  2021  pidof -> /sbin/killall5
# -rwxr-xr-x 1 root root       30968 Feb 25  2022  pidwait
# lrwxrwxrwx 1 root root          26 Nov 10 04:56  pinentry -> /etc/alternatives/pinentry
# -rwxr-xr-x 1 root root       60056 Mar 24  2022  pinentry-curses
# -rwxr-xr-x 1 root root       35232 Feb  7  2022  pinky
# -rwxr-xr-x 1 root root       18736 Feb 26  2022  pkaction
# -rwxr-xr-x 1 root root       22832 Feb 26  2022  pkcheck
# -rwsr-xr-x 1 root root       30872 Feb 26  2022  pkexec
# -rwxr-xr-x 2 root root       51488 Mar 24  2022  pkg-config
# -rwxr-xr-x 1 root root       44576 Nov  4  2021  pkgdata
# lrwxrwxrwx 1 root root           5 Feb 25  2022  pkill -> pgrep
# -rwxr-xr-x 1 root root       18736 Feb 26  2022  pkttyagent
# -rwxr-xr-x 1 root root        4536 May 23  2023  pl2pm
# -rwxr-xr-x 1 root root       22904 Sep 25  2023  pldd
# -rwxr-xr-x 1 root root       35064 Feb 25  2022  pmap
# -rwxr-xr-x 1 root root       59784 Mar 24  2022  pngfix
# -rwxr-xr-x 1 root root       14648 Mar 24  2022  png-fix-itxt
# -rwxr-xr-x 1 root root        4137 May 23  2023  pod2html
# -rwxr-xr-x 1 root root       15034 May 23  2023  pod2man
# -rwxr-xr-x 1 root root       10803 May 23  2023  pod2text
# -rwxr-xr-x 1 root root        4107 May 23  2023  pod2usage
# -rwxr-xr-x 1 root root        3658 May 23  2023  podchecker
# -rwxr-xr-x 1 root root      178252 Mar 23  2022  pprof-symbolize
# -rwxr-xr-x 1 root root       68168 Feb  7  2022  pr
# -rwxr-xr-x 1 root root       55784 Mar 23  2022  preconv
# lrwxrwxrwx 1 root root          11 Oct 31  2021  prename -> file-rename
# -rwxr-xr-x 1 root root       31104 Feb  7  2022  printenv
# -rwxr-xr-x 1 root root       51632 Feb  7  2022  printf
# -rwxr-xr-x 1 root root       27528 Feb 21  2022  prlimit
# -rwxr-xr-x 1 root root        2709 Mar  4  2022  profile2mat
# -rwxr-xr-x 1 root root       18672 Mar  9  2023  protoc
# -rwxr-xr-x 1 root root       13658 May 23  2023  prove
# -rwxr-xr-x 1 root root       22912 Mar 24  2022  prtstat
# -rwxr-xr-x 1 root root       22792 Feb  6  2022  prune
# -rwxr-xr-x 1 root root      141776 Feb 25  2022  ps
# -rwxr-xr-x 1 root root       14640 Mar 24  2022  pslog
# -rwxr-xr-x 1 root root       36168 Mar 24  2022  pstree
# lrwxrwxrwx 1 root root           6 Mar 24  2022  pstree.x11 -> pstree
# -rwxr-xr-x 1 root root        4168 Apr 10  2019  pt
# -rwxr-xr-x 1 root root        3566 May 23  2023  ptar
# -rwxr-xr-x 1 root root        2645 May 23  2023  ptardiff
# -rwxr-xr-x 1 root root        4395 May 23  2023  ptargrep
# -rwxr-xr-x 1 root root      129584 Feb  7  2022  ptx
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  pwd
# -rwxr-xr-x 1 root root       14568 Feb 25  2022  pwdx
# -rwxr-xr-x 1 root root        7813 Aug 18  2022  py3clean
# -rwxr-xr-x 1 root root       13191 Aug 18  2022  py3compile
# lrwxrwxrwx 1 root root          31 Aug 18  2022  py3versions -> ../share/python3/py3versions.py
# lrwxrwxrwx 1 root root           9 Aug 18  2022  pydoc3 -> pydoc3.10
# -rwxr-xr-x 1 root root          79 Nov 20 15:14  pydoc3.10
# lrwxrwxrwx 1 root root          13 Aug 18  2022  pygettext3 -> pygettext3.10
# -rwxr-xr-x 1 root root       24235 Jun  6  2023  pygettext3.10
# lrwxrwxrwx 1 root root          10 Aug 18  2022  python3 -> python3.10
# -rwxr-xr-x 1 root root     5904904 Nov 20 15:14  python3.10
# lrwxrwxrwx 1 root root          34 Nov 20 15:14  python3.10-config -> x86_64-linux-gnu-python3.10-config
# lrwxrwxrwx 1 root root          17 Aug 18  2022  python3-config -> python3.10-config
# -rwxr-xr-x 1 root root       18736 May 19  2022  qt-faststart
# -rwxr-xr-x 1 root root     1109352 Mar 16  2022  quickbook
# -rwxr-xr-x 1 root root        9002 Mar  1 23:46  R
# lrwxrwxrwx 1 root root          23 Jun  4  2023  ranlib -> x86_64-linux-gnu-ranlib
# lrwxrwxrwx 1 root root           4 Jan  6  2022  rbash -> bash
# lrwxrwxrwx 1 root root          21 Apr 23 13:15  rcp -> /etc/alternatives/rcp
# -rwxr-xr-x 1 root root      100880 Mar 24  2022  rdma
# lrwxrwxrwx 1 root root          24 Jun  4  2023  readelf -> x86_64-linux-gnu-readelf
# -rwxr-xr-x 1 root root       39328 Feb  7  2022  readlink
# -rwxr-xr-x 1 root root       39328 Feb  7  2022  realpath
# lrwxrwxrwx 1 root root          24 Apr 23 13:15  rename -> /etc/alternatives/rename
# -rwxr-xr-x 1 root root       14712 Feb 21  2022  renice
# lrwxrwxrwx 1 root root           4 May 16  2023  reset -> tset
# -rwxr-xr-x 1 root root       22904 Feb 21  2022  resizepart
# -rwxr-xr-x 1 root root      133656 Nov 21 20:57  resolvectl
# -rwxr-xr-x 1 root root       14712 Feb 21  2022  rev
# -rwxr-xr-x 1 root root          30 Jan 29  2020  rgrep
# lrwxrwxrwx 1 root root          24 Apr 23 13:15  rlogin -> /etc/alternatives/rlogin
# -rwxr-xr-x 1 root root       59904 Feb  7  2022  rm
# -rwxr-xr-x 1 root root       43424 Feb  7  2022  rmdir
# lrwxrwxrwx 1 root root          22 Apr 23 13:18  rmic -> /etc/alternatives/rmic
# lrwxrwxrwx 1 root root          22 Apr 23 13:18  rmid -> /etc/alternatives/rmid
# lrwxrwxrwx 1 root root          29 Apr 23 13:18  rmiregistry -> /etc/alternatives/rmiregistry
# -rwxr-xr-x 1 root root         208 Mar 24  2022  routef
# -rwxr-xr-x 1 root root        1656 Mar 24  2022  routel
# -rwxr-xr-x 1 root root       96864 Mar 25  2022  rpcgen
# -rwxr-xr-x 1 root root       12639 Feb 27  2023  rrsync
# -rwxr-xr-x 1 root root       14496 Mar  1 23:46  Rscript
# lrwxrwxrwx 1 root root          21 Apr 23 13:15  rsh -> /etc/alternatives/rsh
# -rwxr-xr-x 1 root root      518272 Feb 27  2023  rsync
# -rwxr-xr-x 1 root root        5136 Feb 27  2023  rsync-ssl
# lrwxrwxrwx 1 root root           6 Mar 24  2022  rtstat -> lnstat
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  runcon
# -rwxr-xr-x 1 root root       27176 Mar 23  2022  run-parts
# lrwxrwxrwx 1 root root          23 Apr 23 13:15  rview -> /etc/alternatives/rview
# lrwxrwxrwx 1 root root          22 Apr 23 13:15  rvim -> /etc/alternatives/rvim
# -rwxr-xr-x 1 root root       10487 Mar 23  2022  savelog
# -rwxr-xr-x 1 root root       26888 Feb  6  2022  sccmap
# -rwxr-xr-x 1 root root      133720 Mar 15 20:28  scp
# -rwxr-xr-x 1 root root       51576 Feb 21  2022  script
# -rwxr-xr-x 1 root root       43384 Feb 21  2022  scriptlive
# -rwxr-xr-x 1 root root       35192 Feb 21  2022  scriptreplay
# -rwxr-xr-x 1 root root       47504 Mar 23  2022  sdiff
# -rwxr-xr-x 1 root root      113224 Mar 25  2022  sed
# -rwxr-xr-x 1 root root        2450 Aug 29  2021  select-editor
# -rwxr-xr-x 1 root root        1290 Aug 29  2021  sensible-browser
# -rwxr-xr-x 1 root root        1269 Aug 29  2021  sensible-editor
# -rwxr-xr-x 1 root root         565 Aug 29  2021  sensible-pager
# -rwxr-xr-x 1 root root       47616 Feb  7  2022  seq
# lrwxrwxrwx 1 root root          27 Apr 23 13:18  serialver -> /etc/alternatives/serialver
# -rwxr-xr-x 1 root root       27280 Feb 21  2022  setarch
# -rwxr-xr-x 1 root root       39296 Feb 21  2022  setpriv
# -rwxr-xr-x 1 root root       14712 Feb 21  2022  setsid
# -rwxr-xr-x 1 root root       35192 Feb 21  2022  setterm
# lrwxrwxrwx 1 root root           3 Feb  6  2022  sfdp -> dot
# -rwxr-xr-x 1 root root      146088 Mar 15 20:28  sftp
# lrwxrwxrwx 1 root root           6 Nov 24  2022  sg -> newgrp
# lrwxrwxrwx 1 root root           4 Mar 23  2022  sh -> dash
# -rwxr-xr-x 1 root root       43424 Feb  7  2022  sha1sum
# -rwxr-xr-x 1 root root       51616 Feb  7  2022  sha224sum
# ...
# lrwxrwxrwx 1 root root          14 Mar  4  2022  shmemrun -> mpirun.openmpi
# -rwxr-xr-x 1 root root       51712 Feb  7  2022  shred
# -rwxr-xr-x 1 root root       47616 Feb  7  2022  shuf
# lrwxrwxrwx 1 root root          21 Jun  4  2023  size -> x86_64-linux-gnu-size
# -rwxr-xr-x 1 root root       30952 Feb 25  2022  skill
# -rwxr-xr-x 1 root root       22768 Feb 25  2022  slabtop
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  sleep
# lrwxrwxrwx 1 root root           3 Mar 15 20:28  slogin -> ssh
# lrwxrwxrwx 1 root root           5 Feb 25  2022  snice -> skill
# -rwxr-xr-x 1 root root       31208 Mar 23  2022  soelim
# -rwxr-xr-x 1 root root      101168 Feb  7  2022  sort
# -rwxr-xr-x 1 root root       19414 May 23  2023  splain
# -rwxr-xr-x 1 root root       52184 Feb  7  2022  split
# -rwxr-xr-x 1 root root       18584 Nov 17  2021  sponge
# -rwxr-xr-x 1 root root      128072 Mar 24  2022  ss
# -rwxr-xr-x 1 root root      846888 Mar 15 20:28  ssh
# -rwxr-xr-x 1 root root      170416 Mar 15 20:28  ssh-add
# -rwxr-sr-x 1 root _ssh      293304 Mar 15 20:28  ssh-agent
# -rwxr-xr-x 1 root root        1455 Mar 13 20:24  ssh-argv0
# -rwxr-xr-x 1 root root       12676 Feb 23  2022  ssh-copy-id
# -rwxr-xr-x 1 root root      457152 Mar 15 20:28  ssh-keygen
# -rwxr-xr-x 1 root root      195008 Mar 15 20:28  ssh-keyscan
# -rwxr-xr-x 1 root root       80392 Feb  7  2022  stat
# -rwxr-xr-x 1 root root       43520 Feb  7  2022  stdbuf
# -rwxr-xr-x 1 root root        7941 May 23  2023  streamzip
# lrwxrwxrwx 1 root root          24 Jun  4  2023  strings -> x86_64-linux-gnu-strings
# lrwxrwxrwx 1 root root          22 Jun  4  2023  strip -> x86_64-linux-gnu-strip
# -rwxr-xr-x 1 root root       76288 Feb  7  2022  stty
# -rwsr-xr-x 1 root root       55672 Feb 21  2022  su
# -rwsr-xr-x 1 root root      232416 Apr  3  2023  sudo
# lrwxrwxrwx 1 root root           4 Apr  3  2023  sudoedit -> sudo
# -rwxr-xr-x 1 root root       89744 Apr  3  2023  sudoreplay
# -rwxr-xr-x 1 root root       35232 Feb  7  2022  sum
# -rwxr-xr-x 1 root root       35232 Feb  7  2022  sync
# -rwxr-xr-x 1 root root     1115760 Nov 21 20:57  systemctl
# lrwxrwxrwx 1 root root          20 Nov 21 20:57  systemd -> /lib/systemd/systemd
# -rwxr-xr-x 1 root root     1809160 Nov 21 20:57  systemd-analyze
# -rwxr-xr-x 1 root root       18928 Nov 21 20:57  systemd-ask-password
# -rwxr-xr-x 1 root root       18816 Nov 21 20:57  systemd-cat
# -rwxr-xr-x 1 root root       23016 Nov 21 20:57  systemd-cgls
# -rwxr-xr-x 1 root root       39312 Nov 21 20:57  systemd-cgtop
# -rwxr-xr-x 1 root root       51744 Nov 21 20:57  systemd-cryptenroll
# -rwxr-xr-x 1 root root       27000 Nov 21 20:57  systemd-delta
# -rwxr-xr-x 1 root root       18808 Nov 21 20:57  systemd-detect-virt
# -rwxr-xr-x 1 root root       22904 Nov 21 20:57  systemd-escape
# -rwxr-xr-x 1 root root       27000 Nov 21 20:57  systemd-id128
# -rwxr-xr-x 1 root root       22928 Nov 21 20:57  systemd-inhibit
# -rwxr-xr-x 1 root root       18928 Nov 21 20:57  systemd-machine-id-setup
# -rwxr-xr-x 1 root root       51808 Nov 21 20:57  systemd-mount
# -rwxr-xr-x 1 root root       22912 Nov 21 20:57  systemd-notify
# -rwxr-xr-x 1 root root       18808 Nov 21 20:57  systemd-path
# -rwxr-xr-x 1 root root       64072 Nov 21 20:57  systemd-run
# -rwxr-xr-x 1 root root       27000 Nov 21 20:57  systemd-socket-activate
# -rwxr-xr-x 1 root root       22912 Nov 21 20:57  systemd-stdio-bridge
# -rwxr-xr-x 1 root root       47608 Nov 21 20:57  systemd-sysext
# -rwxr-xr-x 1 root root       64184 Nov 21 20:57  systemd-sysusers
# -rwxr-xr-x 1 root root      100936 Nov 21 20:57  systemd-tmpfiles
# -rwxr-xr-x 1 root root       35192 Nov 21 20:57  systemd-tty-ask-password-agent
# lrwxrwxrwx 1 root root          13 Nov 21 20:57  systemd-umount -> systemd-mount
# -rwxr-xr-x 1 root root       18744 May 16  2023  tabs
# -rwxr-xr-x 1 root root      104864 Feb  7  2022  tac
# -rwxr-xr-x 1 root root       68120 Feb  7  2022  tail
# -rwxr-xr-x 1 root root      517952 Feb 15  2023  tar
# -rwxr-xr-x 1 root root       22904 Feb 21  2022  taskset
# -rwxr-xr-x 1 root root      129512 Mar 23  2022  tbl
# -rwxr-xr-x 1 root root       13695 Apr 10  2019  tcldocstrip
# lrwxrwxrwx 1 root root           8 Mar 25  2022  tclsh -> tclsh8.6
# -rwxr-xr-x 1 root root       14488 Mar 25  2022  tclsh8.6
# -rwxr-xr-x 1 root root        7654 Mar 25  2022  tcltk-depends
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  tee
# -rwxr-xr-x 1 root root       14360 Mar 23  2022  tempfile
# -rwxr-xr-x 1 root root       43440 Feb  7  2022  test
# -rwxr-xr-x 1 root root       88488 May 16  2023  tic
# -rwxr-xr-x 1 root root       47480 Nov 21 20:57  timedatectl
# -rwxr-xr-x 1 root root       39872 Feb  7  2022  timeout
# -rwxr-xr-x 1 root root       18680 Feb 25  2022  tload
# -rwxr-xr-x 1 root root      971320 Jan 31  2023  tmux
# -rwxr-xr-x 1 root root       22840 May 16  2023  toe
# -rwxr-xr-x 1 root root      133184 Feb 25  2022  top
# -rwxr-xr-x 1 root root       92672 Feb  7  2022  touch
# -rwxr-xr-x 1 root root       26968 May 16  2023  tput
# -rwxr-xr-x 1 root root       47616 Feb  7  2022  tr
# -rwxr-xr-x 1 root root       18696 Feb  6  2022  tred
# -rwxr-xr-x 1 root root      735856 Mar 23  2022  troff
# -rwxr-xr-x 1 root root       26928 Feb  7  2022  true
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  truncate
# -rwxr-xr-x 1 root root        4619 Nov 17  2021  ts
# -rwxr-xr-x 1 root root       26944 May 16  2023  tset
# -rwxr-xr-x 1 root root       47616 Feb  7  2022  tsort
# -rwxr-xr-x 1 root root       31232 Feb  7  2022  tty
# lrwxrwxrwx 1 root root           3 Feb  6  2022  twopi -> dot
# -rwxr-xr-x 1 root root       15378 Sep 25  2023  tzselect
# -rwxr-xr-x 1 root root       41883 Jun 16  2020  ucf
# -rwxr-xr-x 1 root root       19367 Jun 16  2020  ucfq
# -rwxr-xr-x 1 root root       10719 Jun 16  2020  ucfr
# -rwxr-xr-x 1 root root       27000 Feb 21  2022  uclampset
# -rwxr-xr-x 1 root root       56144 Nov  4  2021  uconv
# -rwxr-xr-x 1 root root       22920 Apr  9 15:32  ul
# -rwxr-xr-x 1 root root       18584 Mar 23  2022  ulockmgr_server
# -rwsr-xr-x 1 root root       35192 Feb 21  2022  umount
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  uname
# -rwxr-xr-x 2 root root        2346 Sep  5  2022  uncompress
# -rwxr-xr-x 1 root root       35352 Feb  7  2022  unexpand
# -rwxr-xr-x 1 root root       18696 Feb  6  2022  unflatten
# -rwxr-xr-x 1 root root       43520 Feb  7  2022  uniq
# -rwxr-xr-x 1 root root       31232 Feb  7  2022  unlink
# lrwxrwxrwx 1 root root          24 Nov 10 05:10  unlzma -> /etc/alternatives/unlzma
# lrwxrwxrwx 1 root root          27 Apr 23 13:18  unpack200 -> /etc/alternatives/unpack200
# lrwxrwxrwx 1 root root          23 Apr 23 13:18  unrar -> /etc/alternatives/unrar
# -rwxr-xr-x 1 root root      306608 Feb 22  2022  unrar-nonfree
# -rwxr-xr-x 1 root root       31328 Feb 21  2022  unshare
# lrwxrwxrwx 1 root root           2 Apr  8  2022  unxz -> xz
# -rwxr-xr-x 2 root root      174512 Feb  1 15:52  unzip
# -rwxr-xr-x 1 root root       80304 Feb  1 15:52  unzipsfx
# -rwxr-xr-x 1 root root       59640 Apr  1  2023  update-alternatives
# -rwxr-xr-x 1 root root       59624 Jan 14  2022  update-mime-database
# -rwxr-xr-x 1 root root       14568 Feb 25  2022  uptime
# -rwxr-xr-x 1 root root       35328 Feb  7  2022  users
# -rwxr-xr-x 1 root root       22904 Feb 21  2022  utmpdump
# -rwxr-xr-x 1 root root      138208 Feb  7  2022  vdir
# lrwxrwxrwx 1 root root          20 Apr 23 13:15  vi -> /etc/alternatives/vi
# -rwxr-xr-x 1 root root        4878 Nov 17  2021  vidir
# lrwxrwxrwx 1 root root          22 Apr 23 13:15  view -> /etc/alternatives/view
# lrwxrwxrwx 1 root root          21 Apr 23 13:15  vim -> /etc/alternatives/vim
# -rwxr-xr-x 1 root root     3787824 Mar 14 09:05  vim.basic
# lrwxrwxrwx 1 root root          25 Apr 23 13:15  vimdiff -> /etc/alternatives/vimdiff
# -rwxr-xr-x 1 root root        1082 Feb  6  2022  vimdot
# -rwxr-xr-x 1 root root        2154 Mar 14 09:05  vimtutor
# -rwxr-xr-x 1 root root        1976 Nov 17  2021  vipe
# -rwxr-xr-x 1 root root       39160 Feb 25  2022  vmstat
# -rwxr-xr-x 1 root root       22760 Feb 25  2022  w
# -rwxr-sr-x 1 root tty        22904 Feb 21  2022  wall
# -rwxr-xr-x 1 root root       27240 Feb 25  2022  watch
# -rwxr-xr-x 1 root root       18744 Jul  4  2022  watchgnupg
# -rwxr-xr-x 1 root root       43432 Feb  7  2022  wc
# -rwxr-xr-x 1 root root       31120 Feb 21  2022  wdctl
# -rwxr-xr-x 1 root root      527376 Jan 24  2022  wget
# -rwxr-xr-x 1 root root       48416 Mar 17  2022  whatis
# -rwxr-xr-x 1 root root       31560 Feb 21  2022  whereis
# lrwxrwxrwx 1 root root          23 Oct  4  2023  which -> /etc/alternatives/which
# -rwxr-xr-x 1 root root         946 Mar 23  2022  which.debianutils
# -rwxr-xr-x 1 root root       51728 Feb  7  2022  who
# -rwxr-xr-x 1 root root       31232 Feb  7  2022  whoami
# lrwxrwxrwx 1 root root           7 Mar 25  2022  wish -> wish8.6
# -rwxr-xr-x 1 root root       14488 Mar 25  2022  wish8.6
# lrwxrwxrwx 1 root root          23 Apr 23 13:15  write -> /etc/alternatives/write
# -rwxr-xr-x 1 root root       22920 Apr  9 15:32  write.ul
# lrwxrwxrwx 1 root root           1 Mar 25  2022  X11 -> .
# lrwxrwxrwx 1 root root           7 Feb 21  2022  x86_64 -> setarch
# -rwxr-xr-x 1 root root     1686840 Jul 11  2023  x86_64-linux-gnu-accel-nvptx-none-gcc-13
# -rwxr-xr-x 1 root root       27344 Jun  4  2023  x86_64-linux-gnu-addr2line
# -rwxr-xr-x 1 root root       55792 Jun  4  2023  x86_64-linux-gnu-ar
# -rwxr-xr-x 1 root root      467352 Jun  4  2023  x86_64-linux-gnu-as
# -rwxr-xr-x 1 root root       22800 Jun  4  2023  x86_64-linux-gnu-c++filt
# lrwxrwxrwx 1 root root           6 Aug  5  2021  x86_64-linux-gnu-cpp -> cpp-11
# -rwxr-xr-x 1 root root      928584 May 13  2023  x86_64-linux-gnu-cpp-11
# -rwxr-xr-x 1 root root     1018800 Jul 11  2023  x86_64-linux-gnu-cpp-13
# -rwxr-xr-x 1 root root     1904000 Jun  4  2023  x86_64-linux-gnu-dwp
# -rwxr-xr-x 1 root root       35552 Jun  4  2023  x86_64-linux-gnu-elfedit
# lrwxrwxrwx 1 root root           6 Aug  5  2021  x86_64-linux-gnu-g++ -> g++-11
# -rwxr-xr-x 1 root root      932680 May 13  2023  x86_64-linux-gnu-g++-11
# -rwxr-xr-x 1 root root     1018800 Jul 11  2023  x86_64-linux-gnu-g++-13
# lrwxrwxrwx 1 root root           6 Aug  5  2021  x86_64-linux-gnu-gcc -> gcc-11
# -rwxr-xr-x 1 root root      928584 May 13  2023  x86_64-linux-gnu-gcc-11
# -rwxr-xr-x 1 root root     1018800 Jul 11  2023  x86_64-linux-gnu-gcc-13
# lrwxrwxrwx 1 root root           9 Aug  5  2021  x86_64-linux-gnu-gcc-ar -> gcc-ar-11
# -rwxr-xr-x 1 root root       27176 May 13  2023  x86_64-linux-gnu-gcc-ar-11
# -rwxr-xr-x 1 root root       27176 Jul 11  2023  x86_64-linux-gnu-gcc-ar-13
# lrwxrwxrwx 1 root root           9 Aug  5  2021  x86_64-linux-gnu-gcc-nm -> gcc-nm-11
# -rwxr-xr-x 1 root root       27176 May 13  2023  x86_64-linux-gnu-gcc-nm-11
# -rwxr-xr-x 1 root root       27176 Jul 11  2023  x86_64-linux-gnu-gcc-nm-13
# lrwxrwxrwx 1 root root          13 Aug  5  2021  x86_64-linux-gnu-gcc-ranlib -> gcc-ranlib-11
# -rwxr-xr-x 1 root root       27176 May 13  2023  x86_64-linux-gnu-gcc-ranlib-11
# -rwxr-xr-x 1 root root       27176 Jul 11  2023  x86_64-linux-gnu-gcc-ranlib-13
# lrwxrwxrwx 1 root root           7 Aug  5  2021  x86_64-linux-gnu-gcov -> gcov-11
# -rwxr-xr-x 1 root root      409608 May 13  2023  x86_64-linux-gnu-gcov-11
# -rwxr-xr-x 1 root root      442424 Jul 11  2023  x86_64-linux-gnu-gcov-13
# lrwxrwxrwx 1 root root          12 Aug  5  2021  x86_64-linux-gnu-gcov-dump -> gcov-dump-11
# -rwxr-xr-x 1 root root      257880 May 13  2023  x86_64-linux-gnu-gcov-dump-11
# -rwxr-xr-x 1 root root      352264 Jul 11  2023  x86_64-linux-gnu-gcov-dump-13
# lrwxrwxrwx 1 root root          12 Aug  5  2021  x86_64-linux-gnu-gcov-tool -> gcov-tool-11
# -rwxr-xr-x 1 root root      282552 May 13  2023  x86_64-linux-gnu-gcov-tool-11
# -rwxr-xr-x 1 root root      311312 Jul 11  2023  x86_64-linux-gnu-gcov-tool-13
# lrwxrwxrwx 1 root root          11 Aug  5  2021  x86_64-linux-gnu-gfortran -> gfortran-11
# -rwxr-xr-x 1 root root      928584 May 13  2023  x86_64-linux-gnu-gfortran-11
# lrwxrwxrwx 1 root root          24 Jun  4  2023  x86_64-linux-gnu-gold -> x86_64-linux-gnu-ld.gold
# -rwxr-xr-x 1 root root      114472 Jun  4  2023  x86_64-linux-gnu-gprof
# lrwxrwxrwx 1 root root          23 Jun  4  2023  x86_64-linux-gnu-ld -> x86_64-linux-gnu-ld.bfd
# -rwxr-xr-x 1 root root     1744376 Jun  4  2023  x86_64-linux-gnu-ld.bfd
# -rwxr-xr-x 1 root root     3189920 Jun  4  2023  x86_64-linux-gnu-ld.gold
# -rwxr-xr-x 1 root root    24887296 May 13  2023  x86_64-linux-gnu-lto-dump-11
# -rwxr-xr-x 1 root root    29282808 Jul 11  2023  x86_64-linux-gnu-lto-dump-13
# -rwxr-xr-x 1 root root       44672 Jun  4  2023  x86_64-linux-gnu-nm
# -rwxr-xr-x 1 root root      166440 Jun  4  2023  x86_64-linux-gnu-objcopy
# -rwxr-xr-x 1 root root      377984 Jun  4  2023  x86_64-linux-gnu-objdump
# lrwxrwxrwx 1 root root          34 Apr 23 13:15  x86_64-linux-gnu-pkg-config -> /usr/share/pkg-config-crosswrapper
# -rwxr-xr-x 1 root root        3123 Nov 20 15:14  x86_64-linux-gnu-python3.10-config
# lrwxrwxrwx 1 root root          34 Aug 18  2022  x86_64-linux-gnu-python3-config -> x86_64-linux-gnu-python3.10-config
# -rwxr-xr-x 1 root root       55792 Jun  4  2023  x86_64-linux-gnu-ranlib
# -rwxr-xr-x 1 root root      780736 Jun  4  2023  x86_64-linux-gnu-readelf
# -rwxr-xr-x 1 root root       31184 Jun  4  2023  x86_64-linux-gnu-size
# -rwxr-xr-x 1 root root       31344 Jun  4  2023  x86_64-linux-gnu-strings
# -rwxr-xr-x 1 root root      166472 Jun  4  2023  x86_64-linux-gnu-strip
# -rwxr-xr-x 2 root root       51488 Mar 24  2022  x86_64-pc-linux-gnu-pkg-config
# -rwxr-xr-x 1 root root       63912 Mar 23  2022  xargs
# -rwxr-xr-x 1 root root       56280 Mar 25  2022  xauth
# -rwxr-xr-x 1 root root       20642 Aug 22  2022  xdg-desktop-icon
# -rwxr-xr-x 1 root root       43280 Aug 22  2022  xdg-desktop-menu
# -rwxr-xr-x 1 root root       26934 Aug 22  2022  xdg-email
# -rwxr-xr-x 1 root root       30032 Aug 22  2022  xdg-icon-resource
# -rwxr-xr-x 1 root root       42126 Aug 22  2022  xdg-mime
# -rwxr-xr-x 1 root root       26075 Aug 22  2022  xdg-open
# -rwxr-xr-x 1 root root       38003 Aug 22  2022  xdg-screensaver
# -rwxr-xr-x 1 root root       38417 Aug 22  2022  xdg-settings
# -rwxr-xr-x 1 root root        1436 Feb 16 18:14  xml2-config
# -rwxr-xr-x 1 root root       43160 Jul  7  2019  xsel
# -rwxr-xr-x 1 root root        5167 May 23  2023  xsubpp
# -rwxr-xr-x 1 root root       18720 Mar 14 09:05  xxd
# -rwxr-xr-x 1 root root       84504 Apr  8  2022  xz
# lrwxrwxrwx 1 root root           2 Apr  8  2022  xzcat -> xz
# lrwxrwxrwx 1 root root           6 Apr  8  2022  xzcmp -> xzdiff
# -rwxr-xr-x 1 root root        7023 Apr  8  2022  xzdiff
# lrwxrwxrwx 1 root root           6 Apr  8  2022  xzegrep -> xzgrep
# lrwxrwxrwx 1 root root           6 Apr  8  2022  xzfgrep -> xzgrep
# -rwxr-xr-x 1 root root        6015 Apr  8  2022  xzgrep
# -rwxr-xr-x 1 root root        1799 Apr  8  2022  xzless
# -rwxr-xr-x 1 root root        2162 Apr  8  2022  xzmore
# -rwxr-xr-x 1 root root       31104 Feb  7  2022  yes
# lrwxrwxrwx 1 root root           8 Mar 23  2022  ypdomainname -> hostname
# -rwxr-xr-x 1 root root        1984 Sep  5  2022  zcat
# -rwxr-xr-x 1 root root        1678 Sep  5  2022  zcmp
# -rwxr-xr-x 1 root root        5898 Sep  5  2022  zdiff
# -rwxr-xr-x 1 root root       26840 Sep 25  2023  zdump
# -rwxr-xr-x 1 root root          29 Sep  5  2022  zegrep
# -rwxr-xr-x 1 root root          29 Sep  5  2022  zfgrep
# -rwxr-xr-x 1 root root        2081 Sep  5  2022  zforce
# -rwxr-xr-x 1 root root        8103 Sep  5  2022  zgrep
# -rwxr-xr-x 1 root root      203768 Mar 25  2022  zip
# -rwxr-xr-x 1 root root       72088 Mar 25  2022  zipcloak
# -rwxr-xr-x 1 root root       60065 May 23  2023  zipdetails
# -rwxr-xr-x 1 root root        2959 Feb  1 15:52  zipgrep
# -rwxr-xr-x 2 root root      174512 Feb  1 15:52  zipinfo
# -rwxr-xr-x 1 root root       63896 Mar 25  2022  zipnote
# -rwxr-xr-x 1 root root       59800 Mar 25  2022  zipsplit
# -rwxr-xr-x 1 root root        2206 Sep  5  2022  zless
# -rwxr-xr-x 1 root root        1842 Sep  5  2022  zmore
# -rwxr-xr-x 1 root root        4577 Sep  5  2022  znew
# -rwxr-xr-x 1 root root        2518 Nov 17  2021  zrun

# %%
# !ln -sfnv /usr/bin/gcc-13 /usr/bin/gcc
# !which gcc
# !ls -l /usr/bin/gcc
# !gcc --version
# Out:
# '/usr/bin/gcc' -> '/usr/bin/gcc-13'
# /usr/bin/gcc
# lrwxrwxrwx 1 root root 15 Apr 24 19:55 /usr/bin/gcc -> /usr/bin/gcc-13
# gcc (Ubuntu 13.1.0-8ubuntu1~22.04) 13.1.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !ls -l /usr/local
# Out:
# total 56
# drwxr-xr-x 1 root root 4096 Apr 23 13:40 bin
# drwxr-xr-x 3 root root 4096 Apr 23 13:40 colab
# lrwxrwxrwx 1 root root   22 Nov 10 04:57 cuda -> /etc/alternatives/cuda
# lrwxrwxrwx 1 root root   25 Nov 10 04:57 cuda-12 -> /etc/alternatives/cuda-12
# drwxr-xr-x 1 root root 4096 Nov 10 05:10 cuda-12.2
# drwxr-xr-x 1 root root 4096 Apr 23 13:35 etc
# drwxr-xr-x 2 root root 4096 Oct  4  2023 games
# drwxr-xr-x 2 root root 4096 Apr 23 13:33 _gcs_config_ops.so
# drwxr-xr-x 1 root root 4096 Apr 23 13:35 include
# drwxr-xr-x 1 root root 4096 Apr 23 13:34 lib
# drwxr-xr-x 3 root root 4096 Apr 23 13:35 lib64
# drwxr-xr-x 3 root root 4096 Apr 23 13:34 licensing
# lrwxrwxrwx 1 root root    9 Oct  4  2023 man -> share/man
# drwxr-xr-x 2 root root 4096 Oct  4  2023 sbin
# drwxr-xr-x 1 root root 4096 Apr 23 13:37 share
# drwxr-xr-x 2 root root 4096 Oct  4  2023 src

# %%
# %%shell
# #ajustar link para cuda-10
# #ln -sfnv /usr/local/cuda-10.0/ /usr/local/cuda
# #instalar matplotlib
# pip install -q matplotlib numpy

# %% [markdown]
# Vamos testar nosso ambiente de programação.

# %%
# %%writefile test.c
#
# #include <omp.h>
# #include <stdio.h>
#
# int main() {
#   int numdevices = omp_get_num_devices();
#   printf("number of devices= %d\n", numdevices);
# }
# Out:
# Writing test.c

# %% [markdown]
# ## Compilando
#
# Para compilar um programa OpenMP para GPUs neste ambiente, use os flags abaixo.

# %%
# %%shell
#
# #clang -fopenmp -fopenmp-targets=nvptx64-nvidia-cuda test.c -o teste
# gcc -fno-lto -fopenmp -fstack-protector test.c -o test
# ./test
# Out:
# number of devices= 1

# %% [markdown]
# Vamos verificar o modelo de GPU alocada.

# %% [markdown]
# ## Cálculo de Pi - versão serial
#
# O programa a seguir calcula o valos re Pi pelo método de integração numérica. Esta primeira versão trabalha de forma serial, somente na CPU. Nas próximas versões, nós faremos melhorias nesse programa para acelerar o seu desempenho.

# %%
# %%writefile ex1-pi_serial.c
# // The OpenMP Common Core - pg. 58
# // https://github.com/tgmattso/OmpCommonCore/blob/master/Book/C/Fig_4.5_poprogseq.c
# #include <stdio.h>
# #include <omp.h>
# static long num_steps = 100000000;
# double step;
# int main ()
# {
#    int i;
#    double x, pi, sum = 0.0;
#    double start_time, run_time;
#
#    step = 1.0 / (double) num_steps;
#
#    start_time = omp_get_wtime();
#
#    for (i = 0; i < num_steps; i++){
#       x = (i + 0.5) * step;
#       sum += 4.0 / (1.0 + x * x);
#    }
#
#    pi = step * sum;
#    run_time = omp_get_wtime() - start_time;
#    printf("pi = \%lf, \%ld steps, \%lf secs\n ",
#                 pi, num_steps, run_time);
# }
# Out:
# Writing ex1-pi_serial.c

# %%
# %%shell
#
# #clang -fopenmp -fopenmp-targets=nvptx64-nvidia-cuda ex1-pi_serial.c -o ex1-pi_serial
# gcc -fno-lto -fopenmp  -fstack-protector ex1-pi_serial.c -o ex1-pi_serial
# ./ex1-pi_serial
# Out:
# pi = 3.141593, 100000000 steps, 0.345453 secs

# %% [markdown]
# ## Uma versão paralela pra CPU - Pi-V1.0.c
#
# O próximo exemplo mostra uma forma de paralelizar o algoritmo para execução em CPU, utilizando os seguintes recursos do OpenMP:
#
# * Regiões paralelas
# * Loops paralelos
# * Redução

# %%
# %%writefile Pi-V1.0.c
#
# #include <stdio.h>
# #include <omp.h>
# //static long num_steps = 100000000;
# static long num_steps = 100000000;
# double step;
# int main ()
# {
#    int i;
#    double x, pi, sum = 0.0;
#    double start_time, run_time;
#
#    step = 1.0 / (double) num_steps;
#
#    start_time = omp_get_wtime();
#    #pragma omp parallel
#    {
#      double x;        /* cada thread terá sua variavel x local */
#      #pragma omp for reduction(+:sum)
#        for (i = 0; i < num_steps; i++){
#           x = (i + 0.5) * step;
#           sum += 4.0 / (1.0 + x * x);
#        }
#    }
#    pi = step * sum;
#    run_time = omp_get_wtime() - start_time;
#    printf("pi = \%20.15lf, \%ld steps, \%lf secs\n ", pi, num_steps, run_time);
# }
# Out:
# Writing Pi-V1.0.c

# %%
# %%shell
#
# #clang -fopenmp -fopenmp-targets=nvptx64-nvidia-cuda Pi-V1.0.c -o Pi-V1.0
# gcc -fno-lto -fopenmp -fstack-protector Pi-V1.0.c -o Pi-V1.0
# ./Pi-V1.0
# Out:
# pi =    3.141592653589910, 100000000 steps, 0.331732 secs

# %% [markdown]
# # Usando a GPU - Pi melhorado V2.0
#
# A seguir, vamos utilizar a GPU para tentar acelerar nosso programa, utilizando:
# * Construção __target__ :
#
#   `#pragma omp target`
#   `#pragma omp parallel for`
#   `     for (i=0;i<N;i++) ...`
#
#   Modifique o programa abaixo, introduzindo a melhoria sugerida:

# %%
# %%writefile pi-par-V2.c
#
# #include <stdio.h>
# #include <omp.h>
# static long num_steps = 100000000;
# double step;
# int main ()
# {
#    int i;
#    double x, pi, sum = 0.0;
#    double start_time, run_time;
#
#    step = 1.0 / (double) num_steps;
#
#    start_time = omp_get_wtime();
#
#    // Remover esta linha para versão dos alunos
#    #pragma omp target map(sum)
#    {
#      // Remover esta linha para versão dos alunos
#      #pragma omp parallel for reduction(+: sum) private(x)
#      for (i = 0; i < num_steps; i++){
#        x = (i + 0.5) * step;
#        sum += 4.0 / (1.0 + x * x);
#      }
#    }
#
#    pi = step * sum;
#    run_time = omp_get_wtime() - start_time;
#    printf("pi = \%lf, \%ld steps, \%lf secs\n ",
#                 pi, num_steps, run_time);
# }
# Out:
# Writing pi-par-V2.c

# %%
# %%shell
#
# #clang -O3 -fopenmp -fopenmp-targets=nvptx64-nvidia-cuda  pi-par-V2.c -o pi-par-V2
# gcc -fno-lto -fopenmp  -fstack-protector pi-par-V2.c -o pi-par-V2
# ./pi-par-V2
# Out:
# pi = 3.141593, 100000000 steps, 0.440774 secs

# %% [markdown]
# __Pergunta:__ O que aconteceu? Compare o tempo de execução com o da CPU.

# %% [markdown]
# ## Perfilamento de código (profiling)
#
# O NVprof é uma ferramenta de profiling, que fornece diversos contadores de desempenho pelos quais podemos ter uma noção do que pode estar indo mal e limitando o desempenho do programa.

# %%
# !nvprof ./pi-par-V2
# Out:
# ==1920== NVPROF is profiling process 1920, command: ./pi-par-V2
# pi = 3.141593, 100000000 steps, 0.439361 secs
#  ==1920== Profiling application: ./pi-par-V2
# ==1920== Profiling result:
# No kernels were profiled.
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#       API calls:   76.21%  95.221ms         1  95.221ms  95.221ms  95.221ms  cuCtxCreate
#                    23.70%  29.617ms         1  29.617ms  29.617ms  29.617ms  cuCtxDestroy
#                     0.07%  81.904us        16  5.1190us     133ns  75.247us  cuDeviceGetAttribute
#                     0.01%  8.6500us         1  8.6500us  8.6500us  8.6500us  cuDeviceGetPCIBusId
#                     0.00%  6.1130us         2  3.0560us     793ns  5.3200us  cuCtxGetDevice
#                     0.00%  5.1820us         1  5.1820us  5.1820us  5.1820us  cuDeviceGetName
#                     0.00%  3.7470us         4     936ns     353ns  2.6290us  cuDeviceGetCount
#                     0.00%  2.7140us         1  2.7140us  2.7140us  2.7140us  cuInit
#                     0.00%  2.2450us         2  1.1220us     467ns  1.7780us  cuDeviceGet
#                     0.00%     621ns         1     621ns     621ns     621ns  cuCtxGetCurrent
#                     0.00%     312ns         1     312ns     312ns     312ns  cuDriverGetVersion

# %% [markdown]
# # Usando a GPU - Pi melhorado V3.0
#
# A seguir, vamos utilizar a GPU para tentar acelerar nosso programa, utilizando:
# * Construção __target__ :
#
#   `#pragma omp target`
#   `#pragma omp teams`
#   `#pragma omp distribute`
#   `     for (i=0;i<N;i++) ...`
#
#
#   Modifique o programa abaixo, introduzindo a melhoria sugerida.
#
#   Para este exercício, não utilize a construção  `#pragma omp parallel for`.

# %%
# %%writefile pi-par-V3.c
#
# #include <stdio.h>
# #include <omp.h>
# static long num_steps = 100000000;
# double step;
# int main ()
# {
#    int i;
#    double x, pi, sum = 0.0;
#    double start_time, run_time;
#
#    step = 1.0 / (double) num_steps;
#
#    start_time = omp_get_wtime();
#    #pragma omp target map(sum)
#    #pragma omp teams reduction(+: sum)
#    {
#      double x;
#      #pragma omp distribute
#      for (i = 0; i < num_steps; i++){
#        x = (i + 0.5) * step;
#        sum += 4.0 / (1.0 + x * x);
#      }
#    }
#
#    pi = step * sum;
#    run_time = omp_get_wtime() - start_time;
#    printf("pi = \%lf, \%ld steps, \%lf secs\n ",
#                 pi, num_steps, run_time);
# }
# Out:
# Writing pi-par-V3.c

# %%
# %%shell
#
# #clang -O3 -fopenmp -fopenmp-targets=nvptx64-nvidia-cuda  pi-par-V3.c -o pi-par-V3
# gcc -fno-lto -fopenmp  -fstack-protector pi-par-V3.c -o pi-par-V3
# ./pi-par-V3
# Out:
# pi = 3.141593, 100000000 steps, 0.417806 secs

# %%
# !nvprof ./pi-par-V3
# Out:
# ==1944== NVPROF is profiling process 1944, command: ./pi-par-V3
# pi = 3.141593, 100000000 steps, 0.533162 secs
#  ==1944== Profiling application: ./pi-par-V3
# ==1944== Profiling result:
# No kernels were profiled.
#             Type  Time(%)      Time     Calls       Avg       Min       Max  Name
#       API calls:   69.10%  76.768ms         1  76.768ms  76.768ms  76.768ms  cuCtxCreate
#                    30.81%  34.236ms         1  34.236ms  34.236ms  34.236ms  cuCtxDestroy
#                     0.07%  76.669us        16  4.7910us     149ns  70.587us  cuDeviceGetAttribute
#                     0.01%  6.1780us         1  6.1780us  6.1780us  6.1780us  cuDeviceGetPCIBusId
#                     0.00%  5.1220us         1  5.1220us  5.1220us  5.1220us  cuDeviceGetName
#                     0.00%  4.5210us         2  2.2600us     473ns  4.0480us  cuCtxGetDevice
#                     0.00%  2.7340us         4     683ns     203ns  1.7710us  cuDeviceGetCount
#                     0.00%  1.6140us         1  1.6140us  1.6140us  1.6140us  cuInit
#                     0.00%  1.0030us         2     501ns     170ns     833ns  cuDeviceGet
#                     0.00%     346ns         1     346ns     346ns     346ns  cuCtxGetCurrent
#                     0.00%     149ns         1     149ns     149ns     149ns  cuDriverGetVersion
